# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
import os
import copy
from glob import glob
import cv2

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
def load_dataset(rel_path='.', mode="train", resize=False, resize_shape=(256, 256)):

    
    if os.path.exists(f"BDP_datasets/{mode}/image.npy") and \
        os.path.exists(f"BDP_datasets/{mode}/label.npy") and \
        os.path.exists(f"BDP_datasets/{mode}/mask.npy"):
        
        new_input_tensor = np.load(f"BDP_datasets/{mode}/image.npy")
        new_label_tensor = np.load(f"BDP_datasets/{mode}/label.npy")
        new_mask_tensor = np.load(f"BDP_datasets/{mode}/mask.npy")
        return new_input_tensor, new_label_tensor, new_mask_tensor
    
    train_image_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/img/*.png')))  #choose img
    train_label_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/segm_BDP/*.tif'))) #choose segm
    train_mask_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/mask/*.png'))) #choose mask
    
    for i, filename in enumerate(train_image_files):
        img = Image.open(filename)
        if resize:
            img = img.resize(resize_shape, Image.ANTIALIAS)
        imgmat = np.array(img).astype('float')
        imgmat = imgmat / 255.0
        if i == 0:
            input_tensor = np.expand_dims(imgmat, axis=0)
        else:
            tmp = np.expand_dims(imgmat, axis=0)
            input_tensor = np.concatenate((input_tensor, tmp), axis=0)
    new_input_tensor = np.moveaxis(input_tensor, 3, 1)
            
    for i, filename in enumerate(train_label_files):
        Img_label = Image.open(filename)
        if resize:
            Img_label = Img_label.resize(resize_shape, Image.ANTIALIAS)
            Img_label = Img_label.convert('1')
        label = np.array(Img_label)
        label = label / 1.0
        if i == 0:
            label_tensor = np.expand_dims(label, axis=0)
        else:
            tmp = np.expand_dims(label, axis=0)
            label_tensor = np.concatenate((label_tensor, tmp), axis=0)
    new_label_tensor = np.stack((label_tensor[:,:,:], 1 - label_tensor[:,:,:]), axis=1)
    
    for i, filename in enumerate(train_mask_files):
        Img_mask = Image.open(filename)
        if resize:
            Img_mask = Img_mask.resize(resize_shape, Image.ANTIALIAS)
            Img_mask = Img_mask.convert('1')
        mask = np.array(Img_mask)
        mask = mask / 1.0
        if i == 0:
            mask_tensor = np.expand_dims(mask, axis=0)
        else:
            tmp = np.expand_dims(mask, axis=0)
            mask_tensor = np.concatenate((mask_tensor, tmp), axis=0)
    new_mask_tensor = np.stack((mask_tensor[:,:,:], mask_tensor[:,:,:]), axis=1)
    
    if not os.path.exists("./BDP_datasets"):
        os.mkdir("./BDP_datasets")
    if not os.path.exists(f"./BDP_datasets/{mode}"):
        os.mkdir(f"./BDP_datasets/{mode}")
    np.save(f"BDP_datasets/{mode}/image.npy", new_input_tensor)
    np.save(f"BDP_datasets/{mode}/label.npy", new_label_tensor)
    np.save(f"BDP_datasets/{mode}/mask.npy", new_mask_tensor)
    
    return new_input_tensor, new_label_tensor, new_mask_tensor

# %%
class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvBNReLU, self).__init__()
        self.convbnrelu = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )          
    def forward(self, x):
        return self.convbnrelu(x)
    

class ConvNoPool(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvNoPool, self).__init__()
        self.convnopool = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )        
    def forward(self, x):
        return self.convnopool(x)

    
class ConvPool(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(ConvPool, self).__init__()
        self.convpool = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
    def forward(self, x):
        return self.convpool(x)
    
class UpsampleConv(nn.Module):
    def __init__(self, in_ch, out_ch, isDeconv=True):
        super(UpsampleConv, self).__init__()
        if isDeconv:
            self.up = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2)
        else:
            self.up = nn.Sequential(
                nn.UpsamplingBilinear2d(scale_factor=2),
                nn.Conv2d(in_ch, out_ch, kernel_size=1)
            )
        self.convtwice = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
            
    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x2.size()[3] - x1.size()[3]
        diffY = x2.size()[2] - x1.size()[2]
        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        x = torch.cat([x2, x1], dim=1)
        x = self.convtwice(x)
        return x

class ConvOut(nn.Module):
    def __init__(self, in_ch):
        super(ConvOut, self).__init__()
        self.convout = nn.Sequential(
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, 1, kernel_size=1),
            nn.Sigmoid()
        )
    def forward(self, x):
        output_ = self.convout(x)
        return output_
    
class Unet(nn.Module):
    def __init__(self, img_ch, fch_base=16, isDeconv=True):
        super(Unet, self).__init__()
        
        self.blocks = nn.ModuleList()
        
        self.down1 = ConvNoPool(img_ch, fch_base)
        self.down2 = ConvPool(fch_base, fch_base * 2)
        self.down3 = ConvPool(fch_base * 2, fch_base * 4)
        self.down4 = ConvPool(fch_base * 4, fch_base * 8)
        
        self.encoder = ConvPool(fch_base * 8, fch_base * 16)
        
        self.up1 = UpsampleConv(fch_base * 16 , fch_base * 8, isDeconv)
        self.up2 = UpsampleConv(fch_base * 8, fch_base * 4, isDeconv)
        self.up3 = UpsampleConv(fch_base * 4, fch_base * 2 , isDeconv)
        self.up4 = UpsampleConv(fch_base * 2, fch_base, isDeconv)
        
        self.out = ConvOut(fch_base)
        
        self.blocks = nn.ModuleList([self.down1, self.down2, self.down3,\
                                     self.down4, self.encoder, self.up1, self.up2,\
                                     self.up3, self.up4, self.out])

    def forward(self, input_):
        d1 = self.down1(input_)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        enc = self.encoder(d4)
        u1 = self.up1(enc, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        output_ = self.out(u4)
        return output_

# %%
from sklearn.metrics import roc_auc_score

def eval_print_metrics(bat_label, bat_pred, bat_mask):
    assert len(bat_label.size()) == 4 and len(bat_pred.size()) == 4
    assert bat_label.size()[1] == 1 and bat_pred.size()[1] == 1
    
    masked_pred = bat_pred * bat_mask
    masked_label = bat_label * bat_mask
    masked_pred_class = (masked_pred > 0.35).float()
    
    precision = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_pred_class)) + 1)
    recall = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_label.float())) + 1)
    f1_score = 2.0 * precision * recall / (precision + recall + 1e-8)
    
    pred_ls = bat_pred.detach().numpy()
    label_ls = np.array(bat_label.detach(), dtype=int)

    pred_ls = np.array(bat_pred[bat_mask > 0].detach())
    label_ls = np.array(bat_label[bat_mask > 0].detach(), dtype=int)
    try:
        bat_auc = roc_auc_score(label_ls, pred_ls)
    except ValueError:
        bat_auc = 0

    print("precision: {:.4f} recall: {:.4f} f1_score: {:.4f} auc: {:.4f}".format(precision, recall, f1_score, bat_auc))

    return precision, recall, f1_score

def paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, cur_bat_num, save_img='BDP_datasets/pred_imgs'):
    w, h = bat_img.size()[2:4]
    for bat_id in range(bat_img.size()[0]):
        img = Image.fromarray(np.moveaxis(np.array(bat_img * 255.0, dtype=np.uint8)[bat_id, :, :, :], 0, 2))
        label = Image.fromarray(np.array(bat_label * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        pred_class = Image.fromarray(np.array(bat_pred_class * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        
        res_id = (cur_bat_num - 1) * batch_size + bat_id
        target = Image.new('RGB', (3 * w, h))
        target.paste(img, box = (0, 0))
        target.paste(label, box = (w, 0))
        target.paste(pred_class, box = (2 * w, 0))
        
        target.save(os.path.join(save_img, "result_{}.png".format(res_id)))
    return target

# %%
# set parameters for training
EPOCHS = 50
BATCH_SIZE = 8

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

unet_ins = Unet(img_ch=3, isDeconv=True)
unet_ins.to(device)

criterion = nn.BCELoss()
# criterion =  torch.nn.functional.binary_cross_entropy(inputs, targets, reduction='mean')

optimizer = torch.optim.SGD(unet_ins.parameters(), lr=0.1)

# %%
import warnings
warnings.filterwarnings('ignore')

def model_train(net, optimizer, criterion, epochs=50, batch_size=2):
    
    best_model_wts = copy.deepcopy(net.state_dict())
    best_epoch_avg_loss = float('inf')
    
    for epoch in range(epochs):
        epoch_tot_loss = 0
        print(f'Epoch [{epoch + 1}/{epochs}]')
        for phase in ['train', 'val']:
            
            if phase == 'train':
                net.train()  
            else:
                net.eval()
            
            x_tensor, y_tensor, m_tensor = load_dataset(mode=phase, resize=True, resize_shape=(256, 256))
    
            num_samples = x_tensor.shape[0]
        
            num_iters = int(np.ceil(num_samples / batch_size))
            shuffle_ids = np.random.permutation(num_samples)
            x_tensor = x_tensor[shuffle_ids, :, :, :]
            y_tensor = y_tensor[shuffle_ids, :, :, :]

            for ite in range(num_iters):
                if not ite == num_iters - 1:
                    start_id, end_id = ite * batch_size, (ite + 1) * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
                else:
                    start_id = ite * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])

                optimizer.zero_grad()
                
                bat_img = bat_img.to(device)
                bat_label = bat_label.to(device)
                
                with torch.set_grad_enabled(phase == 'train'):
                    bat_pred = net(bat_img)
                    loss = criterion(bat_pred, bat_label.float())
                    # masked_pred = bat_pred * bat_mask
                    # masked_label = bat_label * bat_mask
                    # loss = criterion(masked_pred, masked_label.float(), reduction='mean')

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()                     

                if not ite == num_iters - 1:
                    epoch_tot_loss += loss.item()
                else:
                    epoch_tot_loss += loss.item()
                    epoch_avg_loss = epoch_tot_loss / (ite + 1)
                    plint = phase if phase == 'train' else 'valid'
                    print("{} avg_loss : {:.4f} ".format(plint, epoch_avg_loss), end = '')
                    eval_print_metrics(bat_label.to('cpu'), bat_pred.to('cpu'), bat_mask)
                
            if phase == 'val' and epoch_avg_loss < best_epoch_avg_loss:
                best_epoch_avg_loss = epoch_avg_loss
                best_model_wts = copy.deepcopy(net.state_dict())
    
    net.load_state_dict(best_model_wts)
    return net

# %%
trained_unet = model_train(unet_ins, optimizer, criterion, batch_size=BATCH_SIZE, epochs=100)
# Out:
# Epoch [1/100]
# train avg_loss : 0.5230 precision: 0.4110 recall: 0.5292 f1_score: 0.4627 auc: 0.8175
# valid avg_loss : 2.3165 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.5640
# Epoch [2/100]
# train avg_loss : 0.2767 precision: 0.5661 recall: 0.3558 f1_score: 0.4370 auc: 0.7973
# valid avg_loss : 1.2919 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.7364
# Epoch [3/100]
# train avg_loss : 0.2252 precision: 0.5153 recall: 0.3060 f1_score: 0.3840 auc: 0.7925
# valid avg_loss : 1.0799 precision: 0.9744 recall: 0.0009 f1_score: 0.0018 auc: 0.8297
# Epoch [4/100]
# train avg_loss : 0.2133 precision: 0.8214 recall: 0.4765 f1_score: 0.6031 auc: 0.9257
# valid avg_loss : 0.9956 precision: 0.9055 recall: 0.1332 f1_score: 0.2322 auc: 0.8803
# Epoch [5/100]
# train avg_loss : 0.2098 precision: 0.5611 recall: 0.3706 f1_score: 0.4464 auc: 0.7930
# valid avg_loss : 0.9584 precision: 0.8711 recall: 0.2735 f1_score: 0.4163 auc: 0.9105
# Epoch [6/100]
# train avg_loss : 0.2076 precision: 0.6191 recall: 0.4062 f1_score: 0.4905 auc: 0.8070
# valid avg_loss : 0.9385 precision: 0.7766 recall: 0.4248 f1_score: 0.5492 auc: 0.9202
# Epoch [7/100]
# train avg_loss : 0.2044 precision: 0.5359 recall: 0.4347 f1_score: 0.4800 auc: 0.8372
# valid avg_loss : 0.9255 precision: 0.7422 recall: 0.4996 f1_score: 0.5972 auc: 0.9286
# Epoch [8/100]
# train avg_loss : 0.2013 precision: 0.7227 recall: 0.5578 f1_score: 0.6296 auc: 0.9289
# valid avg_loss : 0.9073 precision: 0.7301 recall: 0.5428 f1_score: 0.6227 auc: 0.9232
# Epoch [9/100]
# train avg_loss : 0.2055 precision: 0.3713 recall: 0.2748 f1_score: 0.3159 auc: 0.7116
# valid avg_loss : 0.9228 precision: 0.7777 recall: 0.5220 f1_score: 0.6247 auc: 0.9295
# Epoch [10/100]
# train avg_loss : 0.1988 precision: 0.6390 recall: 0.6005 f1_score: 0.6192 auc: 0.9326
# valid avg_loss : 0.8920 precision: 0.7449 recall: 0.5613 f1_score: 0.6402 auc: 0.9322
# Epoch [11/100]
# train avg_loss : 0.1977 precision: 0.6305 recall: 0.5988 f1_score: 0.6143 auc: 0.9266
# valid avg_loss : 0.8867 precision: 0.7494 recall: 0.5395 f1_score: 0.6273 auc: 0.9300
# Epoch [12/100]
# train avg_loss : 0.1974 precision: 0.7477 recall: 0.6096 f1_score: 0.6717 auc: 0.9481
# valid avg_loss : 0.8854 precision: 0.7074 recall: 0.5978 f1_score: 0.6480 auc: 0.9314
# Epoch [13/100]
# train avg_loss : 0.2028 precision: 0.3871 recall: 0.2927 f1_score: 0.3333 auc: 0.7019
# valid avg_loss : 0.9076 precision: 0.7486 recall: 0.5271 f1_score: 0.6186 auc: 0.9337
# Epoch [14/100]
# train avg_loss : 0.1993 precision: 0.5493 recall: 0.4540 f1_score: 0.4971 auc: 0.8225
# valid avg_loss : 0.8918 precision: 0.7333 recall: 0.5787 f1_score: 0.6469 auc: 0.9413
# Epoch [15/100]
# train avg_loss : 0.1973 precision: 0.7257 recall: 0.5120 f1_score: 0.6004 auc: 0.9071
# valid avg_loss : 0.8837 precision: 0.7553 recall: 0.5545 f1_score: 0.6395 auc: 0.9320
# Epoch [16/100]
# train avg_loss : 0.1980 precision: 0.4723 recall: 0.4425 f1_score: 0.4569 auc: 0.8039
# valid avg_loss : 0.8909 precision: 0.7877 recall: 0.5185 f1_score: 0.6254 auc: 0.9406
# Epoch [17/100]
# train avg_loss : 0.1960 precision: 0.7621 recall: 0.5668 f1_score: 0.6501 auc: 0.9362
# valid avg_loss : 0.8771 precision: 0.7061 recall: 0.6193 f1_score: 0.6599 auc: 0.9318
# Epoch [18/100]
# train avg_loss : 0.1969 precision: 0.4732 recall: 0.4318 f1_score: 0.4515 auc: 0.8088
# valid avg_loss : 0.8833 precision: 0.7539 recall: 0.5275 f1_score: 0.6207 auc: 0.9321
# Epoch [19/100]
# train avg_loss : 0.1966 precision: 0.5591 recall: 0.4804 f1_score: 0.5168 auc: 0.8289
# valid avg_loss : 0.8774 precision: 0.6878 recall: 0.6004 f1_score: 0.6411 auc: 0.9333
# Epoch [20/100]
# train avg_loss : 0.1966 precision: 0.5591 recall: 0.4342 f1_score: 0.4888 auc: 0.8229
# valid avg_loss : 0.8823 precision: 0.7434 recall: 0.5861 f1_score: 0.6554 auc: 0.9378
# Epoch [21/100]
# train avg_loss : 0.1967 precision: 0.5571 recall: 0.4489 f1_score: 0.4972 auc: 0.8164
# valid avg_loss : 0.8780 precision: 0.7223 recall: 0.6363 f1_score: 0.6766 auc: 0.9429
# Epoch [22/100]
# train avg_loss : 0.1944 precision: 0.7453 recall: 0.5843 f1_score: 0.6550 auc: 0.9250
# valid avg_loss : 0.8661 precision: 0.7034 recall: 0.5858 f1_score: 0.6392 auc: 0.9362
# Epoch [23/100]
# train avg_loss : 0.1921 precision: 0.6361 recall: 0.6158 f1_score: 0.6258 auc: 0.9309
# valid avg_loss : 0.8599 precision: 0.7489 recall: 0.6163 f1_score: 0.6761 auc: 0.9401
# Epoch [24/100]
# train avg_loss : 0.1934 precision: 0.7989 recall: 0.5872 f1_score: 0.6769 auc: 0.9433
# valid avg_loss : 0.8623 precision: 0.7005 recall: 0.6537 f1_score: 0.6763 auc: 0.9452
# Epoch [25/100]
# train avg_loss : 0.1960 precision: 0.5026 recall: 0.4235 f1_score: 0.4597 auc: 0.8002
# valid avg_loss : 0.8736 precision: 0.7595 recall: 0.5763 f1_score: 0.6554 auc: 0.9411
# Epoch [26/100]
# train avg_loss : 0.1947 precision: 0.4533 recall: 0.4027 f1_score: 0.4265 auc: 0.7914
# valid avg_loss : 0.8763 precision: 0.7631 recall: 0.5010 f1_score: 0.6049 auc: 0.9303
# Epoch [27/100]
# train avg_loss : 0.1934 precision: 0.5201 recall: 0.4926 f1_score: 0.5060 auc: 0.8141
# valid avg_loss : 0.8633 precision: 0.6936 recall: 0.6622 f1_score: 0.6775 auc: 0.9397
# Epoch [28/100]
# train avg_loss : 0.1925 precision: 0.7847 recall: 0.6056 f1_score: 0.6836 auc: 0.9421
# valid avg_loss : 0.8566 precision: 0.7263 recall: 0.6235 f1_score: 0.6710 auc: 0.9442
# Epoch [29/100]
# train avg_loss : 0.1913 precision: 0.7373 recall: 0.5905 f1_score: 0.6558 auc: 0.9364
# valid avg_loss : 0.8509 precision: 0.7047 recall: 0.6022 f1_score: 0.6494 auc: 0.9276
# Epoch [30/100]
# train avg_loss : 0.1959 precision: 0.4538 recall: 0.3956 f1_score: 0.4227 auc: 0.7500
# valid avg_loss : 0.8726 precision: 0.7434 recall: 0.5744 f1_score: 0.6480 auc: 0.9388
# Epoch [31/100]
# train avg_loss : 0.1899 precision: 0.7202 recall: 0.6457 f1_score: 0.6809 auc: 0.9441
# valid avg_loss : 0.8454 precision: 0.6840 recall: 0.6957 f1_score: 0.6898 auc: 0.9446
# Epoch [32/100]
# train avg_loss : 0.1899 precision: 0.7201 recall: 0.6136 f1_score: 0.6626 auc: 0.9378
# valid avg_loss : 0.8464 precision: 0.7098 recall: 0.6371 f1_score: 0.6715 auc: 0.9443
# Epoch [33/100]
# train avg_loss : 0.1920 precision: 0.5795 recall: 0.4977 f1_score: 0.5355 auc: 0.8439
# valid avg_loss : 0.8560 precision: 0.6961 recall: 0.6494 f1_score: 0.6719 auc: 0.9470
# Epoch [34/100]
# train avg_loss : 0.1912 precision: 0.5409 recall: 0.4901 f1_score: 0.5142 auc: 0.8168
# valid avg_loss : 0.8547 precision: 0.7166 recall: 0.5962 f1_score: 0.6509 auc: 0.9352
# Epoch [35/100]
# train avg_loss : 0.1880 precision: 0.7298 recall: 0.6309 f1_score: 0.6768 auc: 0.9264
# valid avg_loss : 0.8384 precision: 0.7427 recall: 0.6169 f1_score: 0.6740 auc: 0.9440
# Epoch [36/100]
# train avg_loss : 0.1888 precision: 0.6889 recall: 0.6341 f1_score: 0.6604 auc: 0.9282
# valid avg_loss : 0.8390 precision: 0.7104 recall: 0.6160 f1_score: 0.6598 auc: 0.9373
# Epoch [37/100]
# train avg_loss : 0.1919 precision: 0.5160 recall: 0.4170 f1_score: 0.4612 auc: 0.8049
# valid avg_loss : 0.8582 precision: 0.7566 recall: 0.5851 f1_score: 0.6599 auc: 0.9405
# Epoch [38/100]
# train avg_loss : 0.1875 precision: 0.7010 recall: 0.6474 f1_score: 0.6731 auc: 0.9260
# valid avg_loss : 0.8329 precision: 0.6930 recall: 0.6720 f1_score: 0.6824 auc: 0.9445
# Epoch [39/100]
# train avg_loss : 0.1864 precision: 0.7071 recall: 0.6351 f1_score: 0.6692 auc: 0.9435
# valid avg_loss : 0.8323 precision: 0.7220 recall: 0.6428 f1_score: 0.6801 auc: 0.9470
# Epoch [40/100]
# train avg_loss : 0.1921 precision: 0.4393 recall: 0.3996 f1_score: 0.4185 auc: 0.7407
# valid avg_loss : 0.8548 precision: 0.7157 recall: 0.6651 f1_score: 0.6894 auc: 0.9501
# Epoch [41/100]
# train avg_loss : 0.1861 precision: 0.6885 recall: 0.6506 f1_score: 0.6690 auc: 0.9489
# valid avg_loss : 0.8304 precision: 0.7144 recall: 0.6788 f1_score: 0.6962 auc: 0.9451
# Epoch [42/100]
# train avg_loss : 0.1895 precision: 0.5939 recall: 0.5016 f1_score: 0.5439 auc: 0.8560
# valid avg_loss : 0.8434 precision: 0.7088 recall: 0.6122 f1_score: 0.6570 auc: 0.9455
# Epoch [43/100]
# train avg_loss : 0.1885 precision: 0.5289 recall: 0.4972 f1_score: 0.5126 auc: 0.8226
# valid avg_loss : 0.8429 precision: 0.6887 recall: 0.6440 f1_score: 0.6656 auc: 0.9376
# Epoch [44/100]
# train avg_loss : 0.1889 precision: 0.5748 recall: 0.5558 f1_score: 0.5651 auc: 0.8428
# valid avg_loss : 0.8358 precision: 0.7095 recall: 0.6805 f1_score: 0.6947 auc: 0.9398
# Epoch [45/100]
# train avg_loss : 0.1867 precision: 0.4348 recall: 0.5079 f1_score: 0.4685 auc: 0.8304
# valid avg_loss : 0.8408 precision: 0.7414 recall: 0.5947 f1_score: 0.6600 auc: 0.9457
# Epoch [46/100]
# train avg_loss : 0.1851 precision: 0.6356 recall: 0.6530 f1_score: 0.6442 auc: 0.9376
# valid avg_loss : 0.8226 precision: 0.6612 recall: 0.7310 f1_score: 0.6943 auc: 0.9513
# Epoch [47/100]
# train avg_loss : 0.1851 precision: 0.6955 recall: 0.6600 f1_score: 0.6773 auc: 0.9465
# valid avg_loss : 0.8236 precision: 0.6628 recall: 0.6818 f1_score: 0.6721 auc: 0.9432
# Epoch [48/100]
# train avg_loss : 0.1838 precision: 0.6464 recall: 0.6659 f1_score: 0.6560 auc: 0.9378
# valid avg_loss : 0.8183 precision: 0.7018 recall: 0.6590 f1_score: 0.6797 auc: 0.9508
# Epoch [49/100]
# train avg_loss : 0.1844 precision: 0.7022 recall: 0.6493 f1_score: 0.6747 auc: 0.9439
# valid avg_loss : 0.8213 precision: 0.6629 recall: 0.6986 f1_score: 0.6803 auc: 0.9476
# Epoch [50/100]
# train avg_loss : 0.1869 precision: 0.5970 recall: 0.5087 f1_score: 0.5493 auc: 0.8525
# valid avg_loss : 0.8344 precision: 0.7372 recall: 0.6908 f1_score: 0.7132 auc: 0.9497
# Epoch [51/100]
# train avg_loss : 0.1860 precision: 0.5508 recall: 0.4987 f1_score: 0.5235 auc: 0.8569
# valid avg_loss : 0.8337 precision: 0.7355 recall: 0.6140 f1_score: 0.6693 auc: 0.9405
# Epoch [52/100]
# train avg_loss : 0.1871 precision: 0.5803 recall: 0.5352 f1_score: 0.5568 auc: 0.8613
# valid avg_loss : 0.8310 precision: 0.7370 recall: 0.6701 f1_score: 0.7020 auc: 0.9511
# Epoch [53/100]
# train avg_loss : 0.1824 precision: 0.6982 recall: 0.6997 f1_score: 0.6989 auc: 0.9544
# valid avg_loss : 0.8117 precision: 0.6997 recall: 0.7351 f1_score: 0.7170 auc: 0.9495
# Epoch [54/100]
# train avg_loss : 0.1831 precision: 0.7260 recall: 0.6562 f1_score: 0.6893 auc: 0.9381
# valid avg_loss : 0.8125 precision: 0.6900 recall: 0.6860 f1_score: 0.6880 auc: 0.9451
# Epoch [55/100]
# train avg_loss : 0.1899 precision: 0.3885 recall: 0.3673 f1_score: 0.3776 auc: 0.7240
# valid avg_loss : 0.8490 precision: 0.8090 recall: 0.5353 f1_score: 0.6443 auc: 0.9463
# Epoch [56/100]
# train avg_loss : 0.1849 precision: 0.5513 recall: 0.5452 f1_score: 0.5483 auc: 0.8359
# valid avg_loss : 0.8221 precision: 0.7529 recall: 0.5863 f1_score: 0.6593 auc: 0.9425
# Epoch [57/100]
# train avg_loss : 0.1835 precision: 0.7371 recall: 0.6417 f1_score: 0.6861 auc: 0.9271
# valid avg_loss : 0.8148 precision: 0.7024 recall: 0.7021 f1_score: 0.7022 auc: 0.9481
# Epoch [58/100]
# train avg_loss : 0.1827 precision: 0.7387 recall: 0.6735 f1_score: 0.7046 auc: 0.9527
# valid avg_loss : 0.8142 precision: 0.6459 recall: 0.7598 f1_score: 0.6982 auc: 0.9510
# Epoch [59/100]
# train avg_loss : 0.1811 precision: 0.6833 recall: 0.6706 f1_score: 0.6769 auc: 0.9513
# valid avg_loss : 0.8091 precision: 0.6980 recall: 0.6949 f1_score: 0.6964 auc: 0.9405
# Epoch [60/100]
# train avg_loss : 0.1849 precision: 0.5773 recall: 0.5030 f1_score: 0.5376 auc: 0.8481
# valid avg_loss : 0.8233 precision: 0.7543 recall: 0.6388 f1_score: 0.6917 auc: 0.9476
# Epoch [61/100]
# train avg_loss : 0.1833 precision: 0.5720 recall: 0.5562 f1_score: 0.5640 auc: 0.8463
# valid avg_loss : 0.8162 precision: 0.7215 recall: 0.7052 f1_score: 0.7133 auc: 0.9530
# Epoch [62/100]
# train avg_loss : 0.1842 precision: 0.6063 recall: 0.5514 f1_score: 0.5776 auc: 0.8649
# valid avg_loss : 0.8215 precision: 0.7644 recall: 0.6234 f1_score: 0.6867 auc: 0.9499
# Epoch [63/100]
# train avg_loss : 0.1810 precision: 0.6795 recall: 0.6822 f1_score: 0.6809 auc: 0.9507
# valid avg_loss : 0.8075 precision: 0.6668 recall: 0.7011 f1_score: 0.6835 auc: 0.9442
# Epoch [64/100]
# train avg_loss : 0.1806 precision: 0.7391 recall: 0.6485 f1_score: 0.6909 auc: 0.9465
# valid avg_loss : 0.8047 precision: 0.6733 recall: 0.7215 f1_score: 0.6966 auc: 0.9491
# Epoch [65/100]
# train avg_loss : 0.1831 precision: 0.5470 recall: 0.5543 f1_score: 0.5506 auc: 0.8671
# valid avg_loss : 0.8192 precision: 0.7826 recall: 0.5732 f1_score: 0.6617 auc: 0.9516
# Epoch [66/100]
# train avg_loss : 0.1805 precision: 0.6914 recall: 0.7031 f1_score: 0.6972 auc: 0.9568
# valid avg_loss : 0.8048 precision: 0.6330 recall: 0.7372 f1_score: 0.6811 auc: 0.9434
# Epoch [67/100]
# train avg_loss : 0.1795 precision: 0.7364 recall: 0.6399 f1_score: 0.6847 auc: 0.9466
# valid avg_loss : 0.7963 precision: 0.6744 recall: 0.7042 f1_score: 0.6889 auc: 0.9517
# Epoch [68/100]
# train avg_loss : 0.1822 precision: 0.5951 recall: 0.5517 f1_score: 0.5726 auc: 0.8540
# valid avg_loss : 0.8132 precision: 0.7273 recall: 0.6124 f1_score: 0.6649 auc: 0.9437
# Epoch [69/100]
# train avg_loss : 0.1798 precision: 0.5988 recall: 0.6929 f1_score: 0.6424 auc: 0.9420
# valid avg_loss : 0.8020 precision: 0.7491 recall: 0.6058 f1_score: 0.6699 auc: 0.9441
# Epoch [70/100]
# train avg_loss : 0.1826 precision: 0.6643 recall: 0.5213 f1_score: 0.5842 auc: 0.8470
# valid avg_loss : 0.8122 precision: 0.7454 recall: 0.6267 f1_score: 0.6809 auc: 0.9459
# Epoch [71/100]
# train avg_loss : 0.1801 precision: 0.7001 recall: 0.6565 f1_score: 0.6776 auc: 0.9426
# valid avg_loss : 0.8000 precision: 0.7118 recall: 0.6564 f1_score: 0.6830 auc: 0.9479
# Epoch [72/100]
# train avg_loss : 0.1781 precision: 0.6904 recall: 0.6765 f1_score: 0.6834 auc: 0.9414
# valid avg_loss : 0.7931 precision: 0.6669 recall: 0.7379 f1_score: 0.7006 auc: 0.9520
# Epoch [73/100]
# train avg_loss : 0.1779 precision: 0.6899 recall: 0.6791 f1_score: 0.6845 auc: 0.9522
# valid avg_loss : 0.7920 precision: 0.7018 recall: 0.6944 f1_score: 0.6981 auc: 0.9446
# Epoch [74/100]
# train avg_loss : 0.1805 precision: 0.5738 recall: 0.5539 f1_score: 0.5637 auc: 0.8728
# valid avg_loss : 0.8038 precision: 0.7047 recall: 0.6560 f1_score: 0.6795 auc: 0.9436
# Epoch [75/100]
# train avg_loss : 0.1769 precision: 0.6324 recall: 0.7096 f1_score: 0.6688 auc: 0.9492
# valid avg_loss : 0.7865 precision: 0.7089 recall: 0.6376 f1_score: 0.6714 auc: 0.9472
# Epoch [76/100]
# train avg_loss : 0.1778 precision: 0.6535 recall: 0.6709 f1_score: 0.6621 auc: 0.9456
# valid avg_loss : 0.7924 precision: 0.6677 recall: 0.7341 f1_score: 0.6993 auc: 0.9468
# Epoch [77/100]
# train avg_loss : 0.1799 precision: 0.6190 recall: 0.5674 f1_score: 0.5921 auc: 0.8462
# valid avg_loss : 0.8031 precision: 0.7586 recall: 0.6234 f1_score: 0.6844 auc: 0.9479
# Epoch [78/100]
# train avg_loss : 0.1775 precision: 0.6860 recall: 0.6950 f1_score: 0.6904 auc: 0.9554
# valid avg_loss : 0.7922 precision: 0.7536 recall: 0.6224 f1_score: 0.6817 auc: 0.9460
# Epoch [79/100]
# train avg_loss : 0.1766 precision: 0.7049 recall: 0.6355 f1_score: 0.6684 auc: 0.9296
# valid avg_loss : 0.7991 precision: 0.6160 recall: 0.7982 f1_score: 0.6954 auc: 0.9524
# Epoch [80/100]
# train avg_loss : 0.1789 precision: 0.7200 recall: 0.6767 f1_score: 0.6977 auc: 0.9411
# valid avg_loss : 0.7963 precision: 0.7019 recall: 0.7216 f1_score: 0.7116 auc: 0.9552
# Epoch [81/100]
# train avg_loss : 0.1778 precision: 0.7309 recall: 0.6898 f1_score: 0.7097 auc: 0.9546
# valid avg_loss : 0.7894 precision: 0.7217 recall: 0.6997 f1_score: 0.7105 auc: 0.9513
# Epoch [82/100]
# train avg_loss : 0.1802 precision: 0.5657 recall: 0.5414 f1_score: 0.5533 auc: 0.8349
# valid avg_loss : 0.8006 precision: 0.7259 recall: 0.6901 f1_score: 0.7075 auc: 0.9450
# Epoch [83/100]
# train avg_loss : 0.1766 precision: 0.7291 recall: 0.7115 f1_score: 0.7202 auc: 0.9577
# valid avg_loss : 0.7851 precision: 0.6627 recall: 0.7378 f1_score: 0.6983 auc: 0.9501
# Epoch [84/100]
# train avg_loss : 0.1755 precision: 0.7360 recall: 0.6883 f1_score: 0.7114 auc: 0.9533
# valid avg_loss : 0.7794 precision: 0.6515 recall: 0.7865 f1_score: 0.7127 auc: 0.9566
# Epoch [85/100]
# train avg_loss : 0.1786 precision: 0.4239 recall: 0.4490 f1_score: 0.4361 auc: 0.8058
# valid avg_loss : 0.7995 precision: 0.6906 recall: 0.6941 f1_score: 0.6924 auc: 0.9467
# Epoch [86/100]
# train avg_loss : 0.1741 precision: 0.7518 recall: 0.6721 f1_score: 0.7097 auc: 0.9508
# valid avg_loss : 0.7758 precision: 0.7021 recall: 0.7212 f1_score: 0.7115 auc: 0.9487
# Epoch [87/100]
# train avg_loss : 0.1757 precision: 0.7423 recall: 0.6908 f1_score: 0.7156 auc: 0.9466
# valid avg_loss : 0.7839 precision: 0.6918 recall: 0.6594 f1_score: 0.6752 auc: 0.9404
# Epoch [88/100]
# train avg_loss : 0.1789 precision: 0.5439 recall: 0.4942 f1_score: 0.5179 auc: 0.8442
# valid avg_loss : 0.8042 precision: 0.7105 recall: 0.6706 f1_score: 0.6900 auc: 0.9381
# Epoch [89/100]
# train avg_loss : 0.1734 precision: 0.6600 recall: 0.6634 f1_score: 0.6617 auc: 0.9522
# valid avg_loss : 0.7768 precision: 0.7379 recall: 0.6427 f1_score: 0.6871 auc: 0.9496
# Epoch [90/100]
# train avg_loss : 0.1768 precision: 0.5148 recall: 0.4975 f1_score: 0.5060 auc: 0.8711
# valid avg_loss : 0.7915 precision: 0.7432 recall: 0.6383 f1_score: 0.6868 auc: 0.9499
# Epoch [91/100]
# train avg_loss : 0.1720 precision: 0.7195 recall: 0.7085 f1_score: 0.7139 auc: 0.9559
# valid avg_loss : 0.7670 precision: 0.6825 recall: 0.7343 f1_score: 0.7075 auc: 0.9539
# Epoch [92/100]
# train avg_loss : 0.1717 precision: 0.7335 recall: 0.6776 f1_score: 0.7045 auc: 0.9508
# valid avg_loss : 0.7665 precision: 0.7217 recall: 0.7160 f1_score: 0.7188 auc: 0.9527
# Epoch [93/100]
# train avg_loss : 0.1726 precision: 0.6531 recall: 0.6905 f1_score: 0.6713 auc: 0.9514
# valid avg_loss : 0.7718 precision: 0.7031 recall: 0.6887 f1_score: 0.6958 auc: 0.9478
# Epoch [94/100]
# train avg_loss : 0.1718 precision: 0.7312 recall: 0.6869 f1_score: 0.7083 auc: 0.9507
# valid avg_loss : 0.7687 precision: 0.7067 recall: 0.7199 f1_score: 0.7132 auc: 0.9507
# Epoch [95/100]
# train avg_loss : 0.1721 precision: 0.7371 recall: 0.6902 f1_score: 0.7128 auc: 0.9567
# valid avg_loss : 0.7683 precision: 0.6595 recall: 0.7372 f1_score: 0.6961 auc: 0.9461
# Epoch [96/100]
# train avg_loss : 0.1736 precision: 0.3609 recall: 0.3921 f1_score: 0.3758 auc: 0.7981
# valid avg_loss : 0.7998 precision: 0.7666 recall: 0.4628 f1_score: 0.5772 auc: 0.9298
# Epoch [97/100]
# train avg_loss : 0.1697 precision: 0.6634 recall: 0.7115 f1_score: 0.6866 auc: 0.9522
# valid avg_loss : 0.7638 precision: 0.6358 recall: 0.7960 f1_score: 0.7069 auc: 0.9552
# Epoch [98/100]
# train avg_loss : 0.1693 precision: 0.6632 recall: 0.7305 f1_score: 0.6952 auc: 0.9564
# valid avg_loss : 0.7578 precision: 0.6770 recall: 0.7275 f1_score: 0.7014 auc: 0.9480
# Epoch [99/100]
# train avg_loss : 0.1714 precision: 0.5870 recall: 0.5667 f1_score: 0.5767 auc: 0.8912
# valid avg_loss : 0.7683 precision: 0.6761 recall: 0.7441 f1_score: 0.7085 auc: 0.9501
# Epoch [100/100]
# train avg_loss : 0.1694 precision: 0.7175 recall: 0.6836 f1_score: 0.7001 auc: 0.9553
# valid avg_loss : 0.7597 precision: 0.7288 recall: 0.6983 f1_score: 0.7132 auc: 0.9497

# %%
def model_test(net, batch_size=2):
    
    x_tensor, y_tensor, m_tensor = load_dataset(mode='test', resize=True, resize_shape=(256, 256))
    num_samples = x_tensor.shape[0]
    num_iters = int(np.ceil(num_samples / batch_size))
    for ite in range(num_iters):
        print("predicting on the {}th batch".format(ite + 1))
        if not ite == num_iters - 1:
            start_id, end_id = ite * batch_size, (ite + 1) * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
        else:
            start_id = ite * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])
            
        bat_pred = net(bat_img.to(device))
        bat_pred = bat_pred.to('cpu')
        bat_pred_class = (bat_pred > 0.35).float() * bat_mask
        
        eval_print_metrics(bat_label, bat_pred, bat_mask)
                
        aa = paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, ite + 1)
        plt.imshow(aa)
        plt.title('last image in batch')
        plt.axis('off')
        plt.show()

    return

if not os.path.exists("./BDP_datasets/pred_imgs"):
    os.mkdir("./BDP_datasets/pred_imgs")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
a = model_test(trained_unet, batch_size=2)
# Out:
# predicting on the 1th batch
# precision: 0.7369 recall: 0.7464 f1_score: 0.7416 auc: 0.9565
# predicting on the 2th batch
# precision: 0.7087 recall: 0.7445 f1_score: 0.7262 auc: 0.9517
# predicting on the 3th batch
# precision: 0.6714 recall: 0.7626 f1_score: 0.7141 auc: 0.9527
# predicting on the 4th batch
# precision: 0.5742 recall: 0.7559 f1_score: 0.6526 auc: 0.9402
# predicting on the 5th batch
# precision: 0.6503 recall: 0.7891 f1_score: 0.7130 auc: 0.9532
# predicting on the 6th batch
# precision: 0.6599 recall: 0.7276 f1_score: 0.6921 auc: 0.9644

# %%
torch.save(trained_unet.state_dict(), 'models/unet_100epochs_data_prep_BDP.pt')

# model_ft = model_ft = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=False)
# num_ftrs = model_ft.classifier.in_features
# model_ft.classifier  = nn.Linear(num_ftrs, len(class_names))
# model_ft.load_state_dict(torch.load('models/dens_4b_24e_17m.pt'))

torch.cuda.empty_cache()
