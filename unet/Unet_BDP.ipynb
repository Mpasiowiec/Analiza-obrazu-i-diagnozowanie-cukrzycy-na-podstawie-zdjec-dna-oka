# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
import os
import copy
from glob import glob
import cv2
import shutil
import time

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
def load_dataset(rel_path='.', mode="train", resize=False, resize_shape=(256, 256)):

    
    if os.path.exists(f"datasets_BDP/{mode}/image.npy") and \
        os.path.exists(f"datasets_BDP/{mode}/label.npy") and \
        os.path.exists(f"datasets_BDP/{mode}/mask.npy"):
        
        new_input_tensor = np.load(f"datasets_BDP/{mode}/image.npy")
        new_label_tensor = np.load(f"datasets_BDP/{mode}/label.npy")
        new_mask_tensor = np.load(f"datasets_BDP/{mode}/mask.npy")
        return new_input_tensor, new_label_tensor, new_mask_tensor
    
    train_image_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/img/*.png')))  #choose img
    train_label_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/segm_BDP/*.tif'))) #choose segm
    train_mask_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/mask/*.png'))) #choose mask
    
    for i, filename in enumerate(train_image_files):
        img = Image.open(filename)
        if resize:
            img = img.resize(resize_shape, Image.ANTIALIAS)
        imgmat = np.array(img).astype('float')
        imgmat = imgmat / 255.0
        if i == 0:
            input_tensor = np.expand_dims(imgmat, axis=0)
        else:
            tmp = np.expand_dims(imgmat, axis=0)
            input_tensor = np.concatenate((input_tensor, tmp), axis=0)
    new_input_tensor = np.moveaxis(input_tensor, 3, 1)
            
    for i, filename in enumerate(train_label_files):
        Img_label = Image.open(filename)
        if resize:
            Img_label = Img_label.resize(resize_shape, Image.ANTIALIAS)
            Img_label = Img_label.convert('1')
        label = np.array(Img_label)
        label = label / 1.0
        if i == 0:
            label_tensor = np.expand_dims(label, axis=0)
        else:
            tmp = np.expand_dims(label, axis=0)
            label_tensor = np.concatenate((label_tensor, tmp), axis=0)
    new_label_tensor = np.stack((label_tensor[:,:,:], 1 - label_tensor[:,:,:]), axis=1)
    
    for i, filename in enumerate(train_mask_files):
        Img_mask = Image.open(filename)
        if resize:
            Img_mask = Img_mask.resize(resize_shape, Image.ANTIALIAS)
            Img_mask = Img_mask.convert('1')
        mask = np.array(Img_mask)
        mask = mask / 1.0
        if i == 0:
            mask_tensor = np.expand_dims(mask, axis=0)
        else:
            tmp = np.expand_dims(mask, axis=0)
            mask_tensor = np.concatenate((mask_tensor, tmp), axis=0)
    new_mask_tensor = np.stack((mask_tensor[:,:,:], mask_tensor[:,:,:]), axis=1)
    
    if not os.path.exists("./datasets_BDP"):
        os.mkdir("./datasets_BDP")
    if not os.path.exists(f"./datasets_BDP/{mode}"):
        os.mkdir(f"./datasets_BDP/{mode}")
    np.save(f"datasets_BDP/{mode}/image.npy", new_input_tensor)
    np.save(f"datasets_BDP/{mode}/label.npy", new_label_tensor)
    np.save(f"datasets_BDP/{mode}/mask.npy", new_mask_tensor)
    
    return new_input_tensor, new_label_tensor, new_mask_tensor

# %%
class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvBNReLU, self).__init__()
        self.convbnrelu = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )          
    def forward(self, x):
        return self.convbnrelu(x)
    

class ConvNoPool(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvNoPool, self).__init__()
        self.convnopool = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )        
    def forward(self, x):
        return self.convnopool(x)

    
class ConvPool(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(ConvPool, self).__init__()
        self.convpool = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
    def forward(self, x):
        return self.convpool(x)
    
class UpsampleConv(nn.Module):
    def __init__(self, in_ch, out_ch, isDeconv=True):
        super(UpsampleConv, self).__init__()
        if isDeconv:
            self.up = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2)
        else:
            self.up = nn.Sequential(
                nn.UpsamplingBilinear2d(scale_factor=2),
                nn.Conv2d(in_ch, out_ch, kernel_size=1)
            )
        self.convtwice = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
            
    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x2.size()[3] - x1.size()[3]
        diffY = x2.size()[2] - x1.size()[2]
        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        x = torch.cat([x2, x1], dim=1)
        x = self.convtwice(x)
        return x

class ConvOut(nn.Module):
    def __init__(self, in_ch):
        super(ConvOut, self).__init__()
        self.convout = nn.Sequential(
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, 1, kernel_size=1),
            nn.Sigmoid()
        )
    def forward(self, x):
        output_ = self.convout(x)
        return output_
    
class Unet(nn.Module):
    def __init__(self, img_ch, fch_base=16, isDeconv=True):
        super(Unet, self).__init__()
        
        self.blocks = nn.ModuleList()
        
        self.down1 = ConvNoPool(img_ch, fch_base)
        self.down2 = ConvPool(fch_base, fch_base * 2)
        self.down3 = ConvPool(fch_base * 2, fch_base * 4)
        self.down4 = ConvPool(fch_base * 4, fch_base * 8)
        
        self.encoder = ConvPool(fch_base * 8, fch_base * 16)
        
        self.up1 = UpsampleConv(fch_base * 16 , fch_base * 8, isDeconv)
        self.up2 = UpsampleConv(fch_base * 8, fch_base * 4, isDeconv)
        self.up3 = UpsampleConv(fch_base * 4, fch_base * 2 , isDeconv)
        self.up4 = UpsampleConv(fch_base * 2, fch_base, isDeconv)
        
        self.out = ConvOut(fch_base)
        
        self.blocks = nn.ModuleList([self.down1, self.down2, self.down3,\
                                     self.down4, self.encoder, self.up1, self.up2,\
                                     self.up3, self.up4, self.out])

    def forward(self, input_):
        d1 = self.down1(input_)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        enc = self.encoder(d4)
        u1 = self.up1(enc, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        output_ = self.out(u4)
        return output_

# %%
from sklearn.metrics import roc_auc_score

def eval_print_metrics(bat_label, bat_pred, bat_mask):
    assert len(bat_label.size()) == 4 and len(bat_pred.size()) == 4
    assert bat_label.size()[1] == 1 and bat_pred.size()[1] == 1
    
    masked_pred = bat_pred * bat_mask
    masked_label = bat_label * bat_mask
    masked_pred_class = (masked_pred > 0.35).float()
    
    precision = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_pred_class)) + 1)
    recall = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_label.float())) + 1)
    f1_score = 2.0 * precision * recall / (precision + recall + 1e-8)
    
    pred_ls = bat_pred.detach().numpy()
    label_ls = np.array(bat_label.detach(), dtype=int)

    pred_ls = np.array(bat_pred[bat_mask > 0].detach())
    label_ls = np.array(bat_label[bat_mask > 0].detach(), dtype=int)
    try:
        bat_auc = roc_auc_score(label_ls, pred_ls)
    except ValueError:
        bat_auc = 0

    print("precision: {:.4f} recall: {:.4f} f1_score: {:.4f} auc: {:.4f}".format(precision, recall, f1_score, bat_auc))

    return precision, recall, f1_score, bat_auc

def paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, cur_bat_num, save_img='pred_imgs_BDP'):
    w, h = bat_img.size()[2:4]
    for bat_id in range(bat_img.size()[0]):
        img = Image.fromarray(np.moveaxis(np.array(bat_img * 255.0, dtype=np.uint8)[bat_id, :, :, :], 0, 2))
        label = Image.fromarray(np.array(bat_label * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        pred_class = Image.fromarray(np.array(bat_pred_class * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        
        res_id = (cur_bat_num - 1) * batch_size + bat_id
        target = Image.new('RGB', (3 * w, h))
        target.paste(img, box = (0, 0))
        target.paste(label, box = (w, 0))
        target.paste(pred_class, box = (2 * w, 0))
        
        target.save(os.path.join(save_img, "result_{}.png".format(res_id)))
    return target

# %%
# set parameters for training
EPOCHS = 50
BATCH_SIZE = 8

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

unet_ins = Unet(img_ch=3, isDeconv=True)
unet_ins.to(device)

criterion = nn.BCELoss()
# criterion =  torch.nn.functional.binary_cross_entropy(inputs, targets, reduction='mean')

optimizer = torch.optim.SGD(unet_ins.parameters(), lr=0.1)

# %%
import warnings
warnings.filterwarnings('ignore')

def model_train(net, optimizer, criterion, epochs=50, batch_size=2):
    since = time.time()
    train_loss_list = []
    train_prec_list = []
    valid_loss_list = []
    valid_prec_list = []
    
    best_model_wts = copy.deepcopy(net.state_dict())
    best_epoch_avg_loss = float('inf')
    
    for epoch in range(epochs):
        epoch_tot_loss = 0
        print(f'Epoch [{epoch + 1}/{epochs}]')
        for phase in ['train', 'val']:
            
            if phase == 'train':
                net.train()  
            else:
                net.eval()
            
            x_tensor, y_tensor, m_tensor = load_dataset(mode=phase, resize=True, resize_shape=(256, 256))
    
            num_samples = x_tensor.shape[0]
        
            num_iters = int(np.ceil(num_samples / batch_size))
            shuffle_ids = np.random.permutation(num_samples)
            x_tensor = x_tensor[shuffle_ids, :, :, :]
            y_tensor = y_tensor[shuffle_ids, :, :, :]

            for ite in range(num_iters):
                if not ite == num_iters - 1:
                    start_id, end_id = ite * batch_size, (ite + 1) * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
                else:
                    start_id = ite * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])

                optimizer.zero_grad()
                
                bat_img = bat_img.to(device)
                bat_label = bat_label.to(device)
                
                with torch.set_grad_enabled(phase == 'train'):
                    bat_pred = net(bat_img)
                    loss = criterion(bat_pred, bat_label.float())
                    # masked_pred = bat_pred * bat_mask
                    # masked_label = bat_label * bat_mask
                    # loss = criterion(masked_pred, masked_label.float(), reduction='mean')

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()                     

                if not ite == num_iters - 1:
                    epoch_tot_loss += loss.item()
                else:
                    epoch_tot_loss += loss.item()
                    epoch_avg_loss = epoch_tot_loss / (ite + 1)
                    plint = phase if phase == 'train' else 'valid'
                    print("{} avg_loss : {:.4f} ".format(plint, epoch_avg_loss), end = '')
                    prec, _, _ = eval_print_metrics(bat_label.to('cpu'), bat_pred.to('cpu'), bat_mask)
             
            if phase == 'train':
                train_loss_list.append(epoch_avg_loss)
                train_prec_list.append(prec)
            else:
                valid_loss_list.append(epoch_avg_loss)
                valid_prec_list.append(prec)
                
            if phase == 'val' and epoch_avg_loss < best_epoch_avg_loss:
                best_epoch_avg_loss = epoch_avg_loss
                best_model_wts = copy.deepcopy(net.state_dict())
                
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best validation loss: {best_epoch_avg_loss:4f}')
    xepoch = np.arange(epochs, dtype=int)+1
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, layout="constrained")
    
    ax1.plot(xepoch, train_loss_list, label='train')
    ax1.plot(xepoch, valid_loss_list, label='valid')
    ax1.legend(loc="center right")
    ax1.set_ylabel('loss')
    
    ax2.plot(xepoch, train_prec_list, label='train')
    ax2.plot(xepoch, valid_prec_list, label='valid')
    ax2.legend(loc="center right")
    ax2.set_ylabel('precistion')
    plt.plot()
    
    net.load_state_dict(best_model_wts)
    return net

# %%
trained_unet = model_train(unet_ins, optimizer, criterion, batch_size=BATCH_SIZE, epochs=100)
# Out:
# Epoch [1/100]
# train avg_loss : 0.6173 precision: 0.1804 recall: 0.7170 f1_score: 0.2883 auc: 0.7179
# valid avg_loss : 2.7518 precision: 0.0945 recall: 1.0000 f1_score: 0.1726 auc: 0.2919
# Epoch [2/100]
# train avg_loss : 0.3699 precision: 0.6878 recall: 0.2847 f1_score: 0.4028 auc: 0.8589
# valid avg_loss : 1.6891 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.6709
# Epoch [3/100]
# train avg_loss : 0.2761 precision: 0.8093 recall: 0.2274 f1_score: 0.3550 auc: 0.8533
# valid avg_loss : 1.2770 precision: 0.7500 recall: 0.0001 f1_score: 0.0002 auc: 0.8064
# Epoch [4/100]
# train avg_loss : 0.2406 precision: 0.7908 recall: 0.2756 f1_score: 0.4088 auc: 0.8736
# valid avg_loss : 1.1160 precision: 0.8859 recall: 0.0635 f1_score: 0.1185 auc: 0.8614
# Epoch [5/100]
# train avg_loss : 0.2255 precision: 0.7837 recall: 0.2785 f1_score: 0.4109 auc: 0.8879
# valid avg_loss : 1.0363 precision: 0.8706 recall: 0.1364 f1_score: 0.2358 auc: 0.8884
# Epoch [6/100]
# train avg_loss : 0.2183 precision: 0.8085 recall: 0.3759 f1_score: 0.5132 auc: 0.8963
# valid avg_loss : 0.9913 precision: 0.7611 recall: 0.3171 f1_score: 0.4477 auc: 0.9047
# Epoch [7/100]
# train avg_loss : 0.2127 precision: 0.7482 recall: 0.3815 f1_score: 0.5053 auc: 0.8915
# valid avg_loss : 0.9603 precision: 0.7572 recall: 0.3508 f1_score: 0.4795 auc: 0.9002
# Epoch [8/100]
# train avg_loss : 0.2094 precision: 0.7800 recall: 0.3981 f1_score: 0.5271 auc: 0.8993
# valid avg_loss : 0.9420 precision: 0.7167 recall: 0.4857 f1_score: 0.5790 auc: 0.9138
# Epoch [9/100]
# train avg_loss : 0.2064 precision: 0.7769 recall: 0.4932 f1_score: 0.6034 auc: 0.9257
# valid avg_loss : 0.9288 precision: 0.6915 recall: 0.5568 f1_score: 0.6168 auc: 0.9179
# Epoch [10/100]
# train avg_loss : 0.2093 precision: 0.4463 recall: 0.2824 f1_score: 0.3460 auc: 0.6926
# valid avg_loss : 0.9553 precision: 0.7944 recall: 0.4303 f1_score: 0.5583 auc: 0.9147
# Epoch [11/100]
# train avg_loss : 0.2038 precision: 0.4846 recall: 0.3788 f1_score: 0.4252 auc: 0.8182
# valid avg_loss : 0.9198 precision: 0.7644 recall: 0.4178 f1_score: 0.5403 auc: 0.9138
# Epoch [12/100]
# train avg_loss : 0.2032 precision: 0.6636 recall: 0.4414 f1_score: 0.5301 auc: 0.8150
# valid avg_loss : 0.9097 precision: 0.6909 recall: 0.4636 f1_score: 0.5549 auc: 0.9100
# Epoch [13/100]
# train avg_loss : 0.2023 precision: 0.6573 recall: 0.3823 f1_score: 0.4834 auc: 0.7935
# valid avg_loss : 0.9091 precision: 0.7650 recall: 0.5082 f1_score: 0.6107 auc: 0.9305
# Epoch [14/100]
# train avg_loss : 0.2003 precision: 0.7377 recall: 0.5284 f1_score: 0.6157 auc: 0.9059
# valid avg_loss : 0.8963 precision: 0.7452 recall: 0.5475 f1_score: 0.6312 auc: 0.9320
# Epoch [15/100]
# train avg_loss : 0.1994 precision: 0.7325 recall: 0.4939 f1_score: 0.5900 auc: 0.9165
# valid avg_loss : 0.8937 precision: 0.7462 recall: 0.4905 f1_score: 0.5919 auc: 0.9173
# Epoch [16/100]
# train avg_loss : 0.1997 precision: 0.7375 recall: 0.5244 f1_score: 0.6129 auc: 0.9012
# valid avg_loss : 0.8922 precision: 0.7150 recall: 0.5694 f1_score: 0.6339 auc: 0.9288
# Epoch [17/100]
# train avg_loss : 0.2024 precision: 0.3564 recall: 0.2866 f1_score: 0.3177 auc: 0.7248
# valid avg_loss : 0.9187 precision: 0.7954 recall: 0.4442 f1_score: 0.5701 auc: 0.9302
# Epoch [18/100]
# train avg_loss : 0.1983 precision: 0.7568 recall: 0.5237 f1_score: 0.6191 auc: 0.9123
# valid avg_loss : 0.8855 precision: 0.7201 recall: 0.5675 f1_score: 0.6347 auc: 0.9319
# Epoch [19/100]
# train avg_loss : 0.2016 precision: 0.4710 recall: 0.3355 f1_score: 0.3918 auc: 0.6893
# valid avg_loss : 0.9032 precision: 0.7752 recall: 0.5186 f1_score: 0.6215 auc: 0.9332
# Epoch [20/100]
# train avg_loss : 0.1977 precision: 0.5984 recall: 0.4867 f1_score: 0.5368 auc: 0.8129
# valid avg_loss : 0.8824 precision: 0.7031 recall: 0.5615 f1_score: 0.6244 auc: 0.9280
# Epoch [21/100]
# train avg_loss : 0.1993 precision: 0.5433 recall: 0.4216 f1_score: 0.4748 auc: 0.8100
# valid avg_loss : 0.8909 precision: 0.7322 recall: 0.5232 f1_score: 0.6103 auc: 0.9307
# Epoch [22/100]
# train avg_loss : 0.1970 precision: 0.5918 recall: 0.4838 f1_score: 0.5324 auc: 0.8400
# valid avg_loss : 0.8816 precision: 0.7422 recall: 0.5566 f1_score: 0.6361 auc: 0.9393
# Epoch [23/100]
# train avg_loss : 0.1977 precision: 0.6380 recall: 0.4472 f1_score: 0.5258 auc: 0.8283
# valid avg_loss : 0.8876 precision: 0.7803 recall: 0.5126 f1_score: 0.6188 auc: 0.9307
# Epoch [24/100]
# train avg_loss : 0.1959 precision: 0.5452 recall: 0.4665 f1_score: 0.5028 auc: 0.8046
# valid avg_loss : 0.8756 precision: 0.7619 recall: 0.5952 f1_score: 0.6683 auc: 0.9426
# Epoch [25/100]
# train avg_loss : 0.1972 precision: 0.5084 recall: 0.4081 f1_score: 0.4527 auc: 0.8059
# valid avg_loss : 0.8873 precision: 0.7703 recall: 0.4413 f1_score: 0.5612 auc: 0.9208
# Epoch [26/100]
# train avg_loss : 0.1937 precision: 0.6497 recall: 0.5947 f1_score: 0.6210 auc: 0.9180
# valid avg_loss : 0.8644 precision: 0.7173 recall: 0.5636 f1_score: 0.6312 auc: 0.9294
# Epoch [27/100]
# train avg_loss : 0.1930 precision: 0.7666 recall: 0.5486 f1_score: 0.6395 auc: 0.9311
# valid avg_loss : 0.8610 precision: 0.7059 recall: 0.5813 f1_score: 0.6375 auc: 0.9269
# Epoch [28/100]
# train avg_loss : 0.1940 precision: 0.6966 recall: 0.5907 f1_score: 0.6393 auc: 0.9185
# valid avg_loss : 0.8641 precision: 0.7056 recall: 0.6781 f1_score: 0.6916 auc: 0.9355
# Epoch [29/100]
# train avg_loss : 0.1962 precision: 0.3678 recall: 0.3323 f1_score: 0.3492 auc: 0.7217
# valid avg_loss : 0.8899 precision: 0.8435 recall: 0.4168 f1_score: 0.5579 auc: 0.9434
# Epoch [30/100]
# train avg_loss : 0.1942 precision: 0.7060 recall: 0.5074 f1_score: 0.5904 auc: 0.8304
# valid avg_loss : 0.8647 precision: 0.7012 recall: 0.5991 f1_score: 0.6462 auc: 0.9400
# Epoch [31/100]
# train avg_loss : 0.1932 precision: 0.7271 recall: 0.5933 f1_score: 0.6534 auc: 0.9372
# valid avg_loss : 0.8593 precision: 0.7042 recall: 0.6503 f1_score: 0.6762 auc: 0.9413
# Epoch [32/100]
# train avg_loss : 0.1917 precision: 0.7325 recall: 0.5892 f1_score: 0.6531 auc: 0.9377
# valid avg_loss : 0.8536 precision: 0.7258 recall: 0.6298 f1_score: 0.6744 auc: 0.9385
# Epoch [33/100]
# train avg_loss : 0.1937 precision: 0.5910 recall: 0.4825 f1_score: 0.5312 auc: 0.8168
# valid avg_loss : 0.8666 precision: 0.7404 recall: 0.6053 f1_score: 0.6661 auc: 0.9333
# Epoch [34/100]
# train avg_loss : 0.1912 precision: 0.7363 recall: 0.6366 f1_score: 0.6828 auc: 0.9458
# valid avg_loss : 0.8505 precision: 0.6441 recall: 0.7011 f1_score: 0.6714 auc: 0.9414
# Epoch [35/100]
# train avg_loss : 0.1895 precision: 0.6922 recall: 0.5827 f1_score: 0.6327 auc: 0.9352
# valid avg_loss : 0.8444 precision: 0.6945 recall: 0.6276 f1_score: 0.6594 auc: 0.9406
# Epoch [36/100]
# train avg_loss : 0.1928 precision: 0.5879 recall: 0.4333 f1_score: 0.4989 auc: 0.8570
# valid avg_loss : 0.8656 precision: 0.7691 recall: 0.5058 f1_score: 0.6103 auc: 0.9301
# Epoch [37/100]
# train avg_loss : 0.1889 precision: 0.6970 recall: 0.5926 f1_score: 0.6406 auc: 0.9359
# valid avg_loss : 0.8408 precision: 0.7013 recall: 0.6361 f1_score: 0.6671 auc: 0.9452
# Epoch [38/100]
# train avg_loss : 0.1920 precision: 0.5859 recall: 0.5335 f1_score: 0.5585 auc: 0.8384
# valid avg_loss : 0.8541 precision: 0.7428 recall: 0.6275 f1_score: 0.6803 auc: 0.9469
# Epoch [39/100]
# train avg_loss : 0.1924 precision: 0.5728 recall: 0.5023 f1_score: 0.5352 auc: 0.8357
# valid avg_loss : 0.8556 precision: 0.7107 recall: 0.6275 f1_score: 0.6665 auc: 0.9366
# Epoch [40/100]
# train avg_loss : 0.1904 precision: 0.5560 recall: 0.5111 f1_score: 0.5326 auc: 0.8240
# valid avg_loss : 0.8475 precision: 0.7370 recall: 0.6228 f1_score: 0.6751 auc: 0.9450
# Epoch [41/100]
# train avg_loss : 0.1916 precision: 0.5727 recall: 0.4435 f1_score: 0.4999 auc: 0.8282
# valid avg_loss : 0.8544 precision: 0.7427 recall: 0.6059 f1_score: 0.6674 auc: 0.9376
# Epoch [42/100]
# train avg_loss : 0.1878 precision: 0.6058 recall: 0.6050 f1_score: 0.6054 auc: 0.9257
# valid avg_loss : 0.8416 precision: 0.7238 recall: 0.5608 f1_score: 0.6319 auc: 0.9366
# Epoch [43/100]
# train avg_loss : 0.1867 precision: 0.6696 recall: 0.5809 f1_score: 0.6221 auc: 0.9347
# valid avg_loss : 0.8411 precision: 0.7724 recall: 0.5359 f1_score: 0.6328 auc: 0.9408
# Epoch [44/100]
# train avg_loss : 0.1896 precision: 0.5459 recall: 0.5143 f1_score: 0.5296 auc: 0.8422
# valid avg_loss : 0.8475 precision: 0.7000 recall: 0.6666 f1_score: 0.6829 auc: 0.9500
# Epoch [45/100]
# train avg_loss : 0.1867 precision: 0.6686 recall: 0.6342 f1_score: 0.6510 auc: 0.9377
# valid avg_loss : 0.8303 precision: 0.6858 recall: 0.6934 f1_score: 0.6896 auc: 0.9467
# Epoch [46/100]
# train avg_loss : 0.1916 precision: 0.4889 recall: 0.5152 f1_score: 0.5017 auc: 0.8279
# valid avg_loss : 0.8518 precision: 0.7386 recall: 0.6490 f1_score: 0.6909 auc: 0.9560
# Epoch [47/100]
# train avg_loss : 0.1872 precision: 0.7938 recall: 0.6044 f1_score: 0.6863 auc: 0.9362
# valid avg_loss : 0.8319 precision: 0.7048 recall: 0.6564 f1_score: 0.6798 auc: 0.9426
# Epoch [48/100]
# train avg_loss : 0.1910 precision: 0.5249 recall: 0.4447 f1_score: 0.4815 auc: 0.8075
# valid avg_loss : 0.8527 precision: 0.7546 recall: 0.5337 f1_score: 0.6252 auc: 0.9405
# Epoch [49/100]
# train avg_loss : 0.1858 precision: 0.6871 recall: 0.6763 f1_score: 0.6817 auc: 0.9434
# valid avg_loss : 0.8264 precision: 0.6304 recall: 0.7320 f1_score: 0.6774 auc: 0.9472
# Epoch [50/100]
# train avg_loss : 0.1881 precision: 0.6674 recall: 0.5298 f1_score: 0.5907 auc: 0.8410
# valid avg_loss : 0.8349 precision: 0.6508 recall: 0.7251 f1_score: 0.6860 auc: 0.9478
# Epoch [51/100]
# train avg_loss : 0.1852 precision: 0.7081 recall: 0.6046 f1_score: 0.6523 auc: 0.9297
# valid avg_loss : 0.8243 precision: 0.6941 recall: 0.6781 f1_score: 0.6860 auc: 0.9429
# Epoch [52/100]
# train avg_loss : 0.1863 precision: 0.7579 recall: 0.6218 f1_score: 0.6831 auc: 0.9540
# valid avg_loss : 0.8266 precision: 0.6561 recall: 0.6855 f1_score: 0.6705 auc: 0.9422
# Epoch [53/100]
# train avg_loss : 0.1868 precision: 0.5591 recall: 0.5186 f1_score: 0.5381 auc: 0.8618
# valid avg_loss : 0.8337 precision: 0.7344 recall: 0.6582 f1_score: 0.6942 auc: 0.9431
# Epoch [54/100]
# train avg_loss : 0.1843 precision: 0.6763 recall: 0.6723 f1_score: 0.6743 auc: 0.9479
# valid avg_loss : 0.8181 precision: 0.6693 recall: 0.7401 f1_score: 0.7029 auc: 0.9536
# Epoch [55/100]
# train avg_loss : 0.1902 precision: 0.4677 recall: 0.4182 f1_score: 0.4416 auc: 0.7568
# valid avg_loss : 0.8489 precision: 0.7960 recall: 0.5403 f1_score: 0.6437 auc: 0.9469
# Epoch [56/100]
# train avg_loss : 0.1880 precision: 0.5611 recall: 0.5209 f1_score: 0.5403 auc: 0.8269
# valid avg_loss : 0.8340 precision: 0.7058 recall: 0.6266 f1_score: 0.6638 auc: 0.9389
# Epoch [57/100]
# train avg_loss : 0.1826 precision: 0.7095 recall: 0.6737 f1_score: 0.6911 auc: 0.9495
# valid avg_loss : 0.8106 precision: 0.7169 recall: 0.7008 f1_score: 0.7087 auc: 0.9516
# Epoch [58/100]
# train avg_loss : 0.1853 precision: 0.4979 recall: 0.5265 f1_score: 0.5118 auc: 0.8428
# valid avg_loss : 0.8314 precision: 0.7345 recall: 0.5900 f1_score: 0.6544 auc: 0.9431
# Epoch [59/100]
# train avg_loss : 0.1867 precision: 0.4747 recall: 0.5118 f1_score: 0.4926 auc: 0.8284
# valid avg_loss : 0.8389 precision: 0.7598 recall: 0.5327 f1_score: 0.6263 auc: 0.9456
# Epoch [60/100]
# train avg_loss : 0.1828 precision: 0.6552 recall: 0.6344 f1_score: 0.6447 auc: 0.9292
# valid avg_loss : 0.8121 precision: 0.6807 recall: 0.6971 f1_score: 0.6888 auc: 0.9476
# Epoch [61/100]
# train avg_loss : 0.1852 precision: 0.5876 recall: 0.5334 f1_score: 0.5592 auc: 0.8483
# valid avg_loss : 0.8270 precision: 0.7520 recall: 0.6048 f1_score: 0.6704 auc: 0.9519
# Epoch [62/100]
# train avg_loss : 0.1811 precision: 0.6292 recall: 0.6883 f1_score: 0.6574 auc: 0.9488
# valid avg_loss : 0.8079 precision: 0.6668 recall: 0.7068 f1_score: 0.6863 auc: 0.9416
# Epoch [63/100]
# train avg_loss : 0.1848 precision: 0.5746 recall: 0.4878 f1_score: 0.5276 auc: 0.8412
# valid avg_loss : 0.8257 precision: 0.7738 recall: 0.5752 f1_score: 0.6599 auc: 0.9348
# Epoch [64/100]
# train avg_loss : 0.1885 precision: 0.4108 recall: 0.3348 f1_score: 0.3689 auc: 0.7299
# valid avg_loss : 0.8578 precision: 0.8235 recall: 0.4043 f1_score: 0.5424 auc: 0.9387
# Epoch [65/100]
# train avg_loss : 0.1868 precision: 0.4518 recall: 0.3842 f1_score: 0.4152 auc: 0.7460
# valid avg_loss : 0.8333 precision: 0.7598 recall: 0.5844 f1_score: 0.6606 auc: 0.9522
# Epoch [66/100]
# train avg_loss : 0.1838 precision: 0.6520 recall: 0.5221 f1_score: 0.5799 auc: 0.8548
# valid avg_loss : 0.8133 precision: 0.7031 recall: 0.7300 f1_score: 0.7163 auc: 0.9501
# Epoch [67/100]
# train avg_loss : 0.1807 precision: 0.7212 recall: 0.6583 f1_score: 0.6883 auc: 0.9496
# valid avg_loss : 0.8042 precision: 0.6775 recall: 0.7477 f1_score: 0.7109 auc: 0.9552
# Epoch [68/100]
# train avg_loss : 0.1861 precision: 0.3720 recall: 0.3903 f1_score: 0.3809 auc: 0.7384
# valid avg_loss : 0.8440 precision: 0.8438 recall: 0.4372 f1_score: 0.5759 auc: 0.9549
# Epoch [69/100]
# train avg_loss : 0.1802 precision: 0.7602 recall: 0.6547 f1_score: 0.7035 auc: 0.9502
# valid avg_loss : 0.7991 precision: 0.6698 recall: 0.7673 f1_score: 0.7152 auc: 0.9551
# Epoch [70/100]
# train avg_loss : 0.1853 precision: 0.3403 recall: 0.3379 f1_score: 0.3391 auc: 0.7092
# valid avg_loss : 0.8449 precision: 0.8516 recall: 0.3531 f1_score: 0.4992 auc: 0.9440
# Epoch [71/100]
# train avg_loss : 0.1802 precision: 0.7625 recall: 0.6669 f1_score: 0.7115 auc: 0.9551
# valid avg_loss : 0.7993 precision: 0.6846 recall: 0.7400 f1_score: 0.7112 auc: 0.9464
# Epoch [72/100]
# train avg_loss : 0.1806 precision: 0.7197 recall: 0.6795 f1_score: 0.6990 auc: 0.9553
# valid avg_loss : 0.8025 precision: 0.7063 recall: 0.7259 f1_score: 0.7159 auc: 0.9512
# Epoch [73/100]
# train avg_loss : 0.1793 precision: 0.6959 recall: 0.6514 f1_score: 0.6729 auc: 0.9380
# valid avg_loss : 0.7984 precision: 0.7345 recall: 0.6847 f1_score: 0.7087 auc: 0.9532
# Epoch [74/100]
# train avg_loss : 0.1798 precision: 0.5523 recall: 0.5704 f1_score: 0.5612 auc: 0.8641
# valid avg_loss : 0.8051 precision: 0.7820 recall: 0.5846 f1_score: 0.6691 auc: 0.9468
# Epoch [75/100]
# train avg_loss : 0.1788 precision: 0.7539 recall: 0.6836 f1_score: 0.7170 auc: 0.9556
# valid avg_loss : 0.7969 precision: 0.6292 recall: 0.7602 f1_score: 0.6886 auc: 0.9479
# Epoch [76/100]
# train avg_loss : 0.1782 precision: 0.7466 recall: 0.6832 f1_score: 0.7135 auc: 0.9568
# valid avg_loss : 0.7952 precision: 0.6551 recall: 0.7755 f1_score: 0.7102 auc: 0.9516
# Epoch [77/100]
# train avg_loss : 0.1815 precision: 0.5974 recall: 0.5316 f1_score: 0.5626 auc: 0.8617
# valid avg_loss : 0.8081 precision: 0.6524 recall: 0.7191 f1_score: 0.6842 auc: 0.9502
# Epoch [78/100]
# train avg_loss : 0.1796 precision: 0.7477 recall: 0.5886 f1_score: 0.6587 auc: 0.9393
# valid avg_loss : 0.7985 precision: 0.6476 recall: 0.7549 f1_score: 0.6971 auc: 0.9455
# Epoch [79/100]
# train avg_loss : 0.1878 precision: 0.2654 recall: 0.2508 f1_score: 0.2579 auc: 0.6235
# valid avg_loss : 0.8542 precision: 0.8375 recall: 0.3919 f1_score: 0.5340 auc: 0.9444
# Epoch [80/100]
# train avg_loss : 0.1818 precision: 0.5611 recall: 0.4732 f1_score: 0.5134 auc: 0.8387
# valid avg_loss : 0.8149 precision: 0.7775 recall: 0.5619 f1_score: 0.6524 auc: 0.9471
# Epoch [81/100]
# train avg_loss : 0.1770 precision: 0.6812 recall: 0.6959 f1_score: 0.6885 auc: 0.9519
# valid avg_loss : 0.7892 precision: 0.6913 recall: 0.6817 f1_score: 0.6865 auc: 0.9467
# Epoch [82/100]
# train avg_loss : 0.1783 precision: 0.7704 recall: 0.6598 f1_score: 0.7108 auc: 0.9589
# valid avg_loss : 0.7988 precision: 0.6161 recall: 0.7832 f1_score: 0.6896 auc: 0.9480
# Epoch [83/100]
# train avg_loss : 0.1783 precision: 0.7565 recall: 0.6875 f1_score: 0.7203 auc: 0.9586
# valid avg_loss : 0.7913 precision: 0.7348 recall: 0.6719 f1_score: 0.7019 auc: 0.9532
# Epoch [84/100]
# train avg_loss : 0.1787 precision: 0.6130 recall: 0.5474 f1_score: 0.5784 auc: 0.8709
# valid avg_loss : 0.7994 precision: 0.7328 recall: 0.5748 f1_score: 0.6442 auc: 0.9447
# Epoch [85/100]
# train avg_loss : 0.1769 precision: 0.5001 recall: 0.5323 f1_score: 0.5157 auc: 0.8426
# valid avg_loss : 0.7965 precision: 0.7955 recall: 0.5664 f1_score: 0.6617 auc: 0.9448
# Epoch [86/100]
# train avg_loss : 0.1755 precision: 0.6709 recall: 0.7220 f1_score: 0.6955 auc: 0.9608
# valid avg_loss : 0.7829 precision: 0.6692 recall: 0.7194 f1_score: 0.6934 auc: 0.9491
# Epoch [87/100]
# train avg_loss : 0.1763 precision: 0.7683 recall: 0.6867 f1_score: 0.7252 auc: 0.9554
# valid avg_loss : 0.7820 precision: 0.7194 recall: 0.6681 f1_score: 0.6928 auc: 0.9477
# Epoch [88/100]
# train avg_loss : 0.1775 precision: 0.5785 recall: 0.5070 f1_score: 0.5404 auc: 0.8652
# valid avg_loss : 0.7926 precision: 0.7045 recall: 0.6698 f1_score: 0.6867 auc: 0.9428
# Epoch [89/100]
# train avg_loss : 0.1763 precision: 0.5146 recall: 0.5318 f1_score: 0.5230 auc: 0.8577
# valid avg_loss : 0.7947 precision: 0.7513 recall: 0.5988 f1_score: 0.6665 auc: 0.9480
# Epoch [90/100]
# train avg_loss : 0.1744 precision: 0.5306 recall: 0.5684 f1_score: 0.5488 auc: 0.8743
# valid avg_loss : 0.7805 precision: 0.6587 recall: 0.7088 f1_score: 0.6828 auc: 0.9418
# Epoch [91/100]
# train avg_loss : 0.1716 precision: 0.6453 recall: 0.7151 f1_score: 0.6784 auc: 0.9584
# valid avg_loss : 0.7781 precision: 0.8173 recall: 0.5600 f1_score: 0.6646 auc: 0.9481
# Epoch [92/100]
# train avg_loss : 0.1820 precision: 0.2840 recall: 0.2454 f1_score: 0.2633 auc: 0.6635
# valid avg_loss : 0.8441 precision: 0.8383 recall: 0.2902 f1_score: 0.4311 auc: 0.9308
# Epoch [93/100]
# train avg_loss : 0.1779 precision: 0.3570 recall: 0.3667 f1_score: 0.3618 auc: 0.7562
# valid avg_loss : 0.8089 precision: 0.7904 recall: 0.5186 f1_score: 0.6263 auc: 0.9478
# Epoch [94/100]
# train avg_loss : 0.1729 precision: 0.7466 recall: 0.6973 f1_score: 0.7211 auc: 0.9600
# valid avg_loss : 0.7699 precision: 0.6680 recall: 0.7480 f1_score: 0.7057 auc: 0.9523
# Epoch [95/100]
# train avg_loss : 0.1713 precision: 0.7053 recall: 0.7103 f1_score: 0.7078 auc: 0.9553
# valid avg_loss : 0.7744 precision: 0.5992 recall: 0.7681 f1_score: 0.6732 auc: 0.9431
# Epoch [96/100]
# train avg_loss : 0.1717 precision: 0.5328 recall: 0.5464 f1_score: 0.5395 auc: 0.8724
# valid avg_loss : 0.7978 precision: 0.8299 recall: 0.3923 f1_score: 0.5328 auc: 0.9406
# Epoch [97/100]
# train avg_loss : 0.1707 precision: 0.7830 recall: 0.6808 f1_score: 0.7283 auc: 0.9513
# valid avg_loss : 0.7774 precision: 0.8093 recall: 0.5101 f1_score: 0.6258 auc: 0.9442
# Epoch [98/100]
# train avg_loss : 0.1729 precision: 0.5137 recall: 0.5386 f1_score: 0.5259 auc: 0.8728
# valid avg_loss : 0.7937 precision: 0.7884 recall: 0.4942 f1_score: 0.6076 auc: 0.9451
# Epoch [99/100]
# train avg_loss : 0.1705 precision: 0.7747 recall: 0.6635 f1_score: 0.7148 auc: 0.9503
# valid avg_loss : 0.7704 precision: 0.6313 recall: 0.7895 f1_score: 0.7016 auc: 0.9465
# Epoch [100/100]
# train avg_loss : 0.1697 precision: 0.7206 recall: 0.6772 f1_score: 0.6982 auc: 0.9552
# valid avg_loss : 0.7983 precision: 0.5332 recall: 0.8405 f1_score: 0.6525 auc: 0.9513
# Training complete in 15m 13s
# Best validation loss: 0.769935

# %%
def model_test(net, batch_size=2):
    
    prec_cul = 0
    rec_cul = 0
    f1_cul = 0
    auc_cul = 0
    
    x_tensor, y_tensor, m_tensor = load_dataset(mode='test', resize=True, resize_shape=(256, 256))
    num_samples = x_tensor.shape[0]
    num_iters = int(np.ceil(num_samples / batch_size))
    for ite in range(num_iters):
        print("predicting on the {}th batch".format(ite + 1))
        if not ite == num_iters - 1:
            start_id, end_id = ite * batch_size, (ite + 1) * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
        else:
            start_id = ite * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])
            
        bat_pred = net(bat_img.to(device))
        bat_pred = bat_pred.to('cpu')
        bat_pred_class = (bat_pred > 0.35).float() * bat_mask
        
        prec, rec, f1, auc = eval_print_metrics(bat_label, bat_pred, bat_mask)
        prec_cul += prec
        rec_cul += rec
        f1_cul += f1
        auc_cul += auc
        aa = paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, ite + 1)
        plt.imshow(aa)
        plt.title('last image in batch')
        plt.axis('off')
        plt.show()
    print("Testing average\nprecision: {:.2f} % recall: {:.2f} % f1_score: {:.4f} auc: {:.4f}".format(100*prec_cul/num_iters, 100*rec_cul/num_iters, f1_cul/num_iters, auc_cul/num_iters))

    return

if os.path.exists("./pred_imgs_BDP"):
    shutil.rmtree("./pred_imgs_BDP")
os.mkdir("./pred_imgs_BDP")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
a = model_test(trained_unet, batch_size=2)
shutil.rmtree('./datasets_BDP')
# Out:
# predicting on the 1th batch
# precision: 0.7293 recall: 0.7606 f1_score: 0.7446 auc: 0.9576
# predicting on the 2th batch
# precision: 0.7093 recall: 0.7427 f1_score: 0.7256 auc: 0.9530
# predicting on the 3th batch
# precision: 0.6486 recall: 0.7845 f1_score: 0.7101 auc: 0.9519
# predicting on the 4th batch
# precision: 0.5662 recall: 0.7614 f1_score: 0.6494 auc: 0.9399
# predicting on the 5th batch
# precision: 0.6479 recall: 0.7861 f1_score: 0.7103 auc: 0.9528
# predicting on the 6th batch
# precision: 0.6075 recall: 0.7700 f1_score: 0.6791 auc: 0.9646
# Testing average
# precision: 65.15 % recall: 76.75 % f1_score: 0.7032 auc: 0.9533

# %%
torch.save(trained_unet.state_dict(), 'models/unet_100epochs_data_prep_BDP.pt')

# model_ft = model_ft = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=False)
# num_ftrs = model_ft.classifier.in_features
# model_ft.classifier  = nn.Linear(num_ftrs, len(class_names))
# model_ft.load_state_dict(torch.load('models/dens_4b_24e_17m.pt'))

torch.cuda.empty_cache()
