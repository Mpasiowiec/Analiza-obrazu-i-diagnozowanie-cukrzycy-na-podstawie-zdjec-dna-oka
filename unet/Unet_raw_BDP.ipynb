# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
import os
import copy
from glob import glob
import cv2

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
def load_dataset(rel_path='.', mode="train", resize=False, resize_shape=(256, 256)):
    
    if os.path.exists(f"raw_BDP_datasets/{mode}/image.npy") and \
        os.path.exists(f"raw_BDP_datasets/{mode}/label.npy") and \
        os.path.exists(f"raw_BDP_datasets/{mode}/mask.npy"):
        
        new_input_tensor = np.load(f"raw_BDP_datasets/{mode}/image.npy")
        new_label_tensor = np.load(f"raw_BDP_datasets/{mode}/label.npy")
        new_mask_tensor = np.load(f"raw_BDP_datasets/{mode}/mask.npy")
        return new_input_tensor, new_label_tensor, new_mask_tensor

    train_image_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/raw_img/*.tif')))  #choose img
    train_label_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/segm_BDP/*.tif'))) #choose segm
    train_mask_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/raw_mask/*.png'))) #choose mask
    
    for i, filename in enumerate(train_image_files):
        img = Image.open(filename)
        if resize:
            img = img.resize(resize_shape, Image.ANTIALIAS)
        imgmat = np.array(img).astype('float')
        imgmat = imgmat / 255.0
        if i == 0:
            input_tensor = np.expand_dims(imgmat, axis=0)
        else:
            tmp = np.expand_dims(imgmat, axis=0)
            input_tensor = np.concatenate((input_tensor, tmp), axis=0)
    new_input_tensor = np.moveaxis(input_tensor, 3, 1)
            
    for i, filename in enumerate(train_label_files):
        Img_label = Image.open(filename)
        if resize:
            Img_label = Img_label.resize(resize_shape, Image.ANTIALIAS)
            Img_label = Img_label.convert('1')
        label = np.array(Img_label)
        label = label / 1.0
        if i == 0:
            label_tensor = np.expand_dims(label, axis=0)
        else:
            tmp = np.expand_dims(label, axis=0)
            label_tensor = np.concatenate((label_tensor, tmp), axis=0)
    new_label_tensor = np.stack((label_tensor[:,:,:], 1 - label_tensor[:,:,:]), axis=1)
    
    for i, filename in enumerate(train_mask_files):
        Img_mask = Image.open(filename)
        if resize:
            Img_mask = Img_mask.resize(resize_shape, Image.ANTIALIAS)
            Img_mask = Img_mask.convert('1')
        mask = np.array(Img_mask)
        mask = mask / 1.0
        if i == 0:
            mask_tensor = np.expand_dims(mask, axis=0)
        else:
            tmp = np.expand_dims(mask, axis=0)
            mask_tensor = np.concatenate((mask_tensor, tmp), axis=0)
    new_mask_tensor = np.stack((mask_tensor[:,:,:], mask_tensor[:,:,:]), axis=1)
    
    if not os.path.exists("./raw_BDP_datasets"):
        os.mkdir("./raw_BDP_datasets")
    if not os.path.exists(f"./raw_BDP_datasets/{mode}"):
        os.mkdir(f"./raw_BDP_datasets/{mode}")
    np.save(f"raw_BDP_datasets/{mode}/image.npy", new_input_tensor)
    np.save(f"raw_BDP_datasets/{mode}/label.npy", new_label_tensor)
    np.save(f"raw_BDP_datasets/{mode}/mask.npy", new_mask_tensor)
    
    return new_input_tensor, new_label_tensor, new_mask_tensor

# %%
class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvBNReLU, self).__init__()
        self.convbnrelu = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )          
    def forward(self, x):
        return self.convbnrelu(x)
    

class ConvNoPool(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvNoPool, self).__init__()
        self.convnopool = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )        
    def forward(self, x):
        return self.convnopool(x)

    
class ConvPool(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(ConvPool, self).__init__()
        self.convpool = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
    def forward(self, x):
        return self.convpool(x)
    
class UpsampleConv(nn.Module):
    def __init__(self, in_ch, out_ch, isDeconv=True):
        super(UpsampleConv, self).__init__()
        if isDeconv:
            self.up = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2)
        else:
            self.up = nn.Sequential(
                nn.UpsamplingBilinear2d(scale_factor=2),
                nn.Conv2d(in_ch, out_ch, kernel_size=1)
            )
        self.convtwice = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
            
    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x2.size()[3] - x1.size()[3]
        diffY = x2.size()[2] - x1.size()[2]
        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        x = torch.cat([x2, x1], dim=1)
        x = self.convtwice(x)
        return x

class ConvOut(nn.Module):
    def __init__(self, in_ch):
        super(ConvOut, self).__init__()
        self.convout = nn.Sequential(
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, 1, kernel_size=1),
            nn.Sigmoid()
        )
    def forward(self, x):
        output_ = self.convout(x)
        return output_
    
class Unet(nn.Module):
    def __init__(self, img_ch, fch_base=16, isDeconv=True):
        super(Unet, self).__init__()
        
        self.blocks = nn.ModuleList()
        
        self.down1 = ConvNoPool(img_ch, fch_base)
        self.down2 = ConvPool(fch_base, fch_base * 2)
        self.down3 = ConvPool(fch_base * 2, fch_base * 4)
        self.down4 = ConvPool(fch_base * 4, fch_base * 8)
        
        self.encoder = ConvPool(fch_base * 8, fch_base * 16)
        
        self.up1 = UpsampleConv(fch_base * 16 , fch_base * 8, isDeconv)
        self.up2 = UpsampleConv(fch_base * 8, fch_base * 4, isDeconv)
        self.up3 = UpsampleConv(fch_base * 4, fch_base * 2 , isDeconv)
        self.up4 = UpsampleConv(fch_base * 2, fch_base, isDeconv)
        
        self.out = ConvOut(fch_base)
        
        self.blocks = nn.ModuleList([self.down1, self.down2, self.down3,\
                                     self.down4, self.encoder, self.up1, self.up2,\
                                     self.up3, self.up4, self.out])

    def forward(self, input_):
        d1 = self.down1(input_)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        enc = self.encoder(d4)
        u1 = self.up1(enc, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        output_ = self.out(u4)
        return output_

# %%
from sklearn.metrics import roc_auc_score

def eval_print_metrics(bat_label, bat_pred, bat_mask):
    assert len(bat_label.size()) == 4 and len(bat_pred.size()) == 4
    assert bat_label.size()[1] == 1 and bat_pred.size()[1] == 1
    
    masked_pred = bat_pred * bat_mask
    masked_label = bat_label * bat_mask
    masked_pred_class = (masked_pred > 0.35).float()
    
    precision = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_pred_class)) + 1)
    recall = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_label.float())) + 1)
    f1_score = 2.0 * precision * recall / (precision + recall + 1e-8)
    
    pred_ls = bat_pred.detach().numpy()
    label_ls = np.array(bat_label.detach(), dtype=int)

    pred_ls = np.array(bat_pred[bat_mask > 0].detach())
    label_ls = np.array(bat_label[bat_mask > 0].detach(), dtype=int)
    try:
        bat_auc = roc_auc_score(label_ls, pred_ls)
    except ValueError:
        bat_auc = 0

    print("precision: {:.4f} recall: {:.4f} f1_score: {:.4f} auc: {:.4f}".format(precision, recall, f1_score, bat_auc))

    return precision, recall, f1_score

def paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, cur_bat_num, save_img='raw_BDP_datasets/pred_imgs'):
    w, h = bat_img.size()[2:4]
    for bat_id in range(bat_img.size()[0]):
        img = Image.fromarray(np.moveaxis(np.array(bat_img * 255.0, dtype=np.uint8)[bat_id, :, :, :], 0, 2))
        label = Image.fromarray(np.array(bat_label * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        pred_class = Image.fromarray(np.array(bat_pred_class * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        
        res_id = (cur_bat_num - 1) * batch_size + bat_id
        target = Image.new('RGB', (3 * w, h))
        target.paste(img, box = (0, 0))
        target.paste(label, box = (w, 0))
        target.paste(pred_class, box = (2 * w, 0))
        
        target.save(os.path.join(save_img, "result_{}.png".format(res_id)))
    return target

# %%
# set parameters for training
EPOCHS = 50
BATCH_SIZE = 8

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

unet_ins = Unet(img_ch=3, isDeconv=True)
unet_ins.to(device)

criterion = nn.BCELoss()
# criterion =  torch.nn.functional.binary_cross_entropy(inputs, targets, reduction='mean')

optimizer = torch.optim.SGD(unet_ins.parameters(), lr=0.1)

# %%
import warnings
warnings.filterwarnings('ignore')

def model_train(net, optimizer, criterion, epochs=50, batch_size=2):
    
    best_model_wts = copy.deepcopy(net.state_dict())
    best_epoch_avg_loss = float('inf')
    
    for epoch in range(epochs):
        epoch_tot_loss = 0
        print(f'Epoch [{epoch + 1}/{epochs}]')
        for phase in ['train', 'val']:
            
            if phase == 'train':
                net.train()  
            else:
                net.eval()
            
            x_tensor, y_tensor, m_tensor = load_dataset(mode=phase, resize=True, resize_shape=(256, 256))
    
            num_samples = x_tensor.shape[0]
        
            num_iters = int(np.ceil(num_samples / batch_size))
            shuffle_ids = np.random.permutation(num_samples)
            x_tensor = x_tensor[shuffle_ids, :, :, :]
            y_tensor = y_tensor[shuffle_ids, :, :, :]

            for ite in range(num_iters):
                if not ite == num_iters - 1:
                    start_id, end_id = ite * batch_size, (ite + 1) * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
                else:
                    start_id = ite * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])

                optimizer.zero_grad()
                
                bat_img = bat_img.to(device)
                bat_label = bat_label.to(device)
                
                with torch.set_grad_enabled(phase == 'train'):
                    bat_pred = net(bat_img)
                    loss = criterion(bat_pred, bat_label.float())
                    # masked_pred = bat_pred * bat_mask
                    # masked_label = bat_label * bat_mask
                    # loss = criterion(masked_pred, masked_label.float(), reduction='mean')

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()                     

                if not ite == num_iters - 1:
                    epoch_tot_loss += loss.item()
                else:
                    epoch_tot_loss += loss.item()
                    epoch_avg_loss = epoch_tot_loss / (ite + 1)
                    plint = phase if phase == 'train' else 'valid'
                    print("{} avg_loss : {:.4f} ".format(plint, epoch_avg_loss), end = '')
                    eval_print_metrics(bat_label.to('cpu'), bat_pred.to('cpu'), bat_mask)
                
            if phase == 'val' and epoch_avg_loss < best_epoch_avg_loss:
                best_epoch_avg_loss = epoch_avg_loss
                best_model_wts = copy.deepcopy(net.state_dict())
    
    net.load_state_dict(best_model_wts)
    return net

# %%
trained_unet = model_train(unet_ins, optimizer, criterion, batch_size=BATCH_SIZE, epochs=100)
# Out:
# Epoch [1/100]
# train avg_loss : 0.5223 precision: 0.1494 recall: 0.0066 f1_score: 0.0127 auc: 0.5382
# valid avg_loss : 2.3659 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.
# valid avg_loss : 0.8014 precision: 0.6355 recall: 0.6812 f1_score: 0.6575 auc: 0.9338
# Epoch [70/100]
# train avg_loss : 0.1790 precision: 0.7452 recall: 0.6256 f1_score: 0.6802 auc: 0.9396
# valid avg_loss : 0.8341 precision: 0.7448 recall: 0.3630 f1_score: 0.4881 auc: 0.8877
# Epoch [71/100]
# train avg_loss : 0.1767 precision: 0.6550 recall: 0.6651 f1_score: 0.6600 auc: 0.9412
# valid avg_loss : 0.7922 precision: 0.6942 recall: 0.6191 f1_score: 0.6545 auc: 0.9406
# Epoch [72/100]
# train avg_loss : 0.1779 precision: 0.6901 recall: 0.6373 f1_score: 0.6627 auc: 0.9457
# valid avg_loss : 0.7963 precision: 0.6717 recall: 0.6124 f1_score: 0.6407 auc: 0.9184
# Epoch [73/100]
# train avg_loss : 0.1801 precision: 0.6053 recall: 0.5071 f1_score: 0.5519 auc: 0.8814
# valid avg_loss : 0.8159 precision: 0.7715 recall: 0.4826 f1_score: 0.5938 auc: 0.9097
# Epoch [74/100]
# train avg_loss : 0.1766 precision: 0.7028 recall: 0.7112 f1_score: 0.7070 auc: 0.9571
# valid avg_loss : 0.7918 precision: 0.6925 recall: 0.6043 f1_score: 0.6454 auc: 0.9290
# Epoch [75/100]
# train avg_loss : 0.1768 precision: 0.7834 recall: 0.5544 f1_score: 0.6493 auc: 0.9349
# valid avg_loss : 0.8125 precision: 0.7805 recall: 0.5288 f1_score: 0.6304 auc: 0.9176
# Epoch [76/100]
# train avg_loss : 0.1832 precision: 0.3143 recall: 0.2666 f1_score: 0.2885 auc: 0.7174
# valid avg_loss : 0.8722 precision: 0.8522 recall: 0.2397 f1_score: 0.3741 auc: 0.8229
# Epoch [77/100]
# train avg_loss : 0.1806 precision: 0.6383 recall: 0.5324 f1_score: 0.5806 auc: 0.8707
# valid avg_loss : 0.8324 precision: 0.6570 recall: 0.5251 f1_score: 0.5837 auc: 0.9039
# Epoch [78/100]
# train avg_loss : 0.1826 precision: 0.5468 recall: 0.4920 f1_score: 0.5180 auc: 0.8342
# valid avg_loss : 0.8414 precision: 0.7243 recall: 0.4537 f1_score: 0.5579 auc: 0.9061
# Epoch [79/100]
# train avg_loss : 0.1780 precision: 0.7241 recall: 0.6253 f1_score: 0.6711 auc: 0.9340
# valid avg_loss : 0.8064 precision: 0.7443 recall: 0.6237 f1_score: 0.6787 auc: 0.9278
# Epoch [80/100]
# train avg_loss : 0.1811 precision: 0.3745 recall: 0.4021 f1_score: 0.3878 auc: 0.7433
# valid avg_loss : 0.8512 precision: 0.8351 recall: 0.3121 f1_score: 0.4544 auc: 0.8846
# Epoch [81/100]
# train avg_loss : 0.1821 precision: 0.3070 recall: 0.2966 f1_score: 0.3017 auc: 0.7130
# valid avg_loss : 0.8353 precision: 0.8496 recall: 0.3706 f1_score: 0.5160 auc: 0.9127
# Epoch [82/100]
# train avg_loss : 0.1769 precision: 0.6769 recall: 0.6116 f1_score: 0.6426 auc: 0.9344
# valid avg_loss : 0.7878 precision: 0.7185 recall: 0.6228 f1_score: 0.6673 auc: 0.9455
# Epoch [83/100]
# train avg_loss : 0.1815 precision: 0.5439 recall: 0.4830 f1_score: 0.5117 auc: 0.8302
# valid avg_loss : 0.8763 precision: 0.8275 recall: 0.2405 f1_score: 0.3727 auc: 0.8764
# Epoch [84/100]
# train avg_loss : 0.1767 precision: 0.6759 recall: 0.6689 f1_score: 0.6724 auc: 0.9494
# valid avg_loss : 0.7907 precision: 0.7056 recall: 0.6576 f1_score: 0.6807 auc: 0.9323
# Epoch [85/100]
# train avg_loss : 0.1778 precision: 0.5253 recall: 0.5416 f1_score: 0.5333 auc: 0.8404
# valid avg_loss : 0.8078 precision: 0.6836 recall: 0.6004 f1_score: 0.6393 auc: 0.9202
# Epoch [86/100]
# train avg_loss : 0.1785 precision: 0.4284 recall: 0.3861 f1_score: 0.4061 auc: 0.7493
# valid avg_loss : 0.7980 precision: 0.7090 recall: 0.5658 f1_score: 0.6294 auc: 0.9213
# Epoch [87/100]
# train avg_loss : 0.1752 precision: 0.6790 recall: 0.6630 f1_score: 0.6709 auc: 0.9421
# valid avg_loss : 0.8050 precision: 0.7289 recall: 0.5435 f1_score: 0.6227 auc: 0.9162
# Epoch [88/100]
# train avg_loss : 0.1752 precision: 0.7267 recall: 0.6888 f1_score: 0.7072 auc: 0.9499
# valid avg_loss : 0.7906 precision: 0.6919 recall: 0.5805 f1_score: 0.6313 auc: 0.9340
# Epoch [89/100]
# train avg_loss : 0.1755 precision: 0.6672 recall: 0.6693 f1_score: 0.6682 auc: 0.9408
# valid avg_loss : 0.8011 precision: 0.6959 recall: 0.4992 f1_score: 0.5813 auc: 0.9220
# Epoch [90/100]
# train avg_loss : 0.1772 precision: 0.5191 recall: 0.5294 f1_score: 0.5242 auc: 0.8520
# valid avg_loss : 0.7905 precision: 0.7089 recall: 0.5820 f1_score: 0.6392 auc: 0.9354
# Epoch [91/100]
# train avg_loss : 0.1753 precision: 0.5694 recall: 0.5431 f1_score: 0.5559 auc: 0.8772
# valid avg_loss : 0.8141 precision: 0.7076 recall: 0.4797 f1_score: 0.5718 auc: 0.8952
# Epoch [92/100]
# train avg_loss : 0.1748 precision: 0.7429 recall: 0.5956 f1_score: 0.6611 auc: 0.9417
# valid avg_loss : 0.8349 precision: 0.5211 recall: 0.5649 f1_score: 0.5421 auc: 0.8518
# Epoch [93/100]
# train avg_loss : 0.1753 precision: 0.7243 recall: 0.7182 f1_score: 0.7212 auc: 0.9585
# valid avg_loss : 0.7800 precision: 0.6828 recall: 0.6909 f1_score: 0.6868 auc: 0.9459
# Epoch [94/100]
# train avg_loss : 0.1767 precision: 0.4618 recall: 0.5073 f1_score: 0.4835 auc: 0.8267
# valid avg_loss : 0.7894 precision: 0.6927 recall: 0.6210 f1_score: 0.6549 auc: 0.9417
# Epoch [95/100]
# train avg_loss : 0.1739 precision: 0.7177 recall: 0.6876 f1_score: 0.7024 auc: 0.9544
# valid avg_loss : 0.7851 precision: 0.7635 recall: 0.5705 f1_score: 0.6530 auc: 0.9339
# Epoch [96/100]
# train avg_loss : 0.1813 precision: 0.2089 recall: 0.2115 f1_score: 0.2102 auc: 0.6122
# valid avg_loss : 0.8382 precision: 0.8485 recall: 0.4135 f1_score: 0.5560 auc: 0.9236
# Epoch [97/100]
# train avg_loss : 0.1754 precision: 0.7133 recall: 0.6935 f1_score: 0.7032 auc: 0.9543
# valid avg_loss : 0.7799 precision: 0.7079 recall: 0.6826 f1_score: 0.6950 auc: 0.9488
# Epoch [98/100]
# train avg_loss : 0.1759 precision: 0.5242 recall: 0.4704 f1_score: 0.4958 auc: 0.8071
# valid avg_loss : 0.7908 precision: 0.7737 recall: 0.5487 f1_score: 0.6420 auc: 0.9336
# Epoch [99/100]
# train avg_loss : 0.1752 precision: 0.6168 recall: 0.5232 f1_score: 0.5661 auc: 0.8729
# valid avg_loss : 0.8459 precision: 0.8676 recall: 0.2326 f1_score: 0.3668 auc: 0.8527
# Epoch [100/100]
# train avg_loss : 0.1806 precision: 0.3695 recall: 0.3791 f1_score: 0.3742 auc: 0.7251
# valid avg_loss : 0.8219 precision: 0.7951 recall: 0.4498 f1_score: 0.5746 auc: 0.9262

# %%
def model_test(net, batch_size=2):
    
    x_tensor, y_tensor, m_tensor = load_dataset(mode='test', resize=True, resize_shape=(256, 256))
    num_samples = x_tensor.shape[0]
    num_iters = int(np.ceil(num_samples / batch_size))
    for ite in range(num_iters):
        print("predicting on the {}th batch".format(ite + 1))
        if not ite == num_iters - 1:
            start_id, end_id = ite * batch_size, (ite + 1) * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
        else:
            start_id = ite * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])
            
        bat_pred = net(bat_img.to(device))
        bat_pred = bat_pred.to('cpu')
        bat_pred_class = (bat_pred > 0.35).float() * bat_mask
        
        eval_print_metrics(bat_label, bat_pred, bat_mask)
                
        aa = paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, ite + 1)
        plt.imshow(aa)
        plt.title('last image in batch')
        plt.axis('off')
        plt.show()

    return

if not os.path.exists("./raw_BDP_datasets/pred_imgs"):
    os.mkdir("./raw_BDP_datasets/pred_imgs")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
a = model_test(trained_unet, batch_size=2)
# Out:
# predicting on the 1th batch
# precision: 0.7509 recall: 0.7067 f1_score: 0.7282 auc: 0.9495
# predicting on the 2th batch
# precision: 0.7076 recall: 0.6576 f1_score: 0.6817 auc: 0.9380
# predicting on the 3th batch
# precision: 0.6488 recall: 0.7754 f1_score: 0.7065 auc: 0.9519
# predicting on the 4th batch
# precision: 0.5847 recall: 0.7519 f1_score: 0.6579 auc: 0.9388
# predicting on the 5th batch
# precision: 0.6315 recall: 0.6879 f1_score: 0.6585 auc: 0.9319
# predicting on the 6th batch
# precision: 0.6493 recall: 0.6759 f1_score: 0.6623 auc: 0.9562

# %%
torch.save(trained_unet.state_dict(), 'models/unet_100epochs_data_raw_BDP.pt')

# model_ft = model_ft = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=False)
# num_ftrs = model_ft.classifier.in_features
# model_ft.classifier  = nn.Linear(num_ftrs, len(class_names))
# model_ft.load_state_dict(torch.load('models/dens_4b_24e_17m.pt'))

torch.cuda.empty_cache()
