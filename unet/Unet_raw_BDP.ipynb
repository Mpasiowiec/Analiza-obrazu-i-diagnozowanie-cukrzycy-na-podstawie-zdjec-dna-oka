# %%
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
import os
import copy
from glob import glob
import cv2
import shutil
import time

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
def load_dataset(rel_path='.', mode="train", resize=False, resize_shape=(256, 256)):
    
    if os.path.exists(f"datasets_raw_BDP/{mode}/image.npy") and \
        os.path.exists(f"datasets_raw_BDP/{mode}/label.npy") and \
        os.path.exists(f"datasets_raw_BDP/{mode}/mask.npy"):
        
        new_input_tensor = np.load(f"datasets_raw_BDP/{mode}/image.npy")
        new_label_tensor = np.load(f"datasets_raw_BDP/{mode}/label.npy")
        new_mask_tensor = np.load(f"datasets_raw_BDP/{mode}/mask.npy")
        return new_input_tensor, new_label_tensor, new_mask_tensor

    train_image_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/img_raw/*.tif')))  #choose img
    train_label_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/segm_BDP/*.tif'))) #choose segm
    train_mask_files = sorted(glob(os.path.join(rel_path, f'data/{mode}/mask_raw/*.png'))) #choose mask
    
    for i, filename in enumerate(train_image_files):
        img = Image.open(filename)
        if resize:
            img = img.resize(resize_shape, Image.ANTIALIAS)
        imgmat = np.array(img).astype('float')
        imgmat = imgmat / 255.0
        if i == 0:
            input_tensor = np.expand_dims(imgmat, axis=0)
        else:
            tmp = np.expand_dims(imgmat, axis=0)
            input_tensor = np.concatenate((input_tensor, tmp), axis=0)
    new_input_tensor = np.moveaxis(input_tensor, 3, 1)
            
    for i, filename in enumerate(train_label_files):
        Img_label = Image.open(filename)
        if resize:
            Img_label = Img_label.resize(resize_shape, Image.ANTIALIAS)
            Img_label = Img_label.convert('1')
        label = np.array(Img_label)
        label = label / 1.0
        if i == 0:
            label_tensor = np.expand_dims(label, axis=0)
        else:
            tmp = np.expand_dims(label, axis=0)
            label_tensor = np.concatenate((label_tensor, tmp), axis=0)
    new_label_tensor = np.stack((label_tensor[:,:,:], 1 - label_tensor[:,:,:]), axis=1)
    
    for i, filename in enumerate(train_mask_files):
        Img_mask = Image.open(filename)
        if resize:
            Img_mask = Img_mask.resize(resize_shape, Image.ANTIALIAS)
            Img_mask = Img_mask.convert('1')
        mask = np.array(Img_mask)
        mask = mask / 1.0
        if i == 0:
            mask_tensor = np.expand_dims(mask, axis=0)
        else:
            tmp = np.expand_dims(mask, axis=0)
            mask_tensor = np.concatenate((mask_tensor, tmp), axis=0)
    new_mask_tensor = np.stack((mask_tensor[:,:,:], mask_tensor[:,:,:]), axis=1)
    
    if not os.path.exists("./datasets_raw_BDP"):
        os.mkdir("./datasets_raw_BDP")
    if not os.path.exists(f"./datasets_raw_BDP/{mode}"):
        os.mkdir(f"./datasets_raw_BDP/{mode}")
    np.save(f"datasets_raw_BDP/{mode}/image.npy", new_input_tensor)
    np.save(f"datasets_raw_BDP/{mode}/label.npy", new_label_tensor)
    np.save(f"datasets_raw_BDP/{mode}/mask.npy", new_mask_tensor)
    
    return new_input_tensor, new_label_tensor, new_mask_tensor

# %%
class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvBNReLU, self).__init__()
        self.convbnrelu = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )          
    def forward(self, x):
        return self.convbnrelu(x)
    

class ConvNoPool(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(ConvNoPool, self).__init__()
        self.convnopool = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )        
    def forward(self, x):
        return self.convnopool(x)

    
class ConvPool(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(ConvPool, self).__init__()
        self.convpool = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
    def forward(self, x):
        return self.convpool(x)
    
class UpsampleConv(nn.Module):
    def __init__(self, in_ch, out_ch, isDeconv=True):
        super(UpsampleConv, self).__init__()
        if isDeconv:
            self.up = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2)
        else:
            self.up = nn.Sequential(
                nn.UpsamplingBilinear2d(scale_factor=2),
                nn.Conv2d(in_ch, out_ch, kernel_size=1)
            )
        self.convtwice = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch)
        )
            
    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x2.size()[3] - x1.size()[3]
        diffY = x2.size()[2] - x1.size()[2]
        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        x = torch.cat([x2, x1], dim=1)
        x = self.convtwice(x)
        return x

class ConvOut(nn.Module):
    def __init__(self, in_ch):
        super(ConvOut, self).__init__()
        self.convout = nn.Sequential(
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, in_ch, kernel_size=1),
            nn.Conv2d(in_ch, 1, kernel_size=1),
            nn.Sigmoid()
        )
    def forward(self, x):
        output_ = self.convout(x)
        return output_
    
class Unet(nn.Module):
    def __init__(self, img_ch, fch_base=16, isDeconv=True):
        super(Unet, self).__init__()
        
        self.blocks = nn.ModuleList()
        
        self.down1 = ConvNoPool(img_ch, fch_base)
        self.down2 = ConvPool(fch_base, fch_base * 2)
        self.down3 = ConvPool(fch_base * 2, fch_base * 4)
        self.down4 = ConvPool(fch_base * 4, fch_base * 8)
        
        self.encoder = ConvPool(fch_base * 8, fch_base * 16)
        
        self.up1 = UpsampleConv(fch_base * 16 , fch_base * 8, isDeconv)
        self.up2 = UpsampleConv(fch_base * 8, fch_base * 4, isDeconv)
        self.up3 = UpsampleConv(fch_base * 4, fch_base * 2 , isDeconv)
        self.up4 = UpsampleConv(fch_base * 2, fch_base, isDeconv)
        
        self.out = ConvOut(fch_base)
        
        self.blocks = nn.ModuleList([self.down1, self.down2, self.down3,\
                                     self.down4, self.encoder, self.up1, self.up2,\
                                     self.up3, self.up4, self.out])

    def forward(self, input_):
        d1 = self.down1(input_)
        d2 = self.down2(d1)
        d3 = self.down3(d2)
        d4 = self.down4(d3)
        enc = self.encoder(d4)
        u1 = self.up1(enc, d4)
        u2 = self.up2(u1, d3)
        u3 = self.up3(u2, d2)
        u4 = self.up4(u3, d1)
        output_ = self.out(u4)
        return output_

# %%
from sklearn.metrics import roc_auc_score

def eval_print_metrics(bat_label, bat_pred, bat_mask):
    assert len(bat_label.size()) == 4 and len(bat_pred.size()) == 4
    assert bat_label.size()[1] == 1 and bat_pred.size()[1] == 1
    
    masked_pred = bat_pred * bat_mask
    masked_label = bat_label * bat_mask
    masked_pred_class = (masked_pred > 0.35).float()
    
    precision = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_pred_class)) + 1)
    recall = float(torch.sum(masked_pred_class * masked_label)) / (float(torch.sum(masked_label.float())) + 1)
    f1_score = 2.0 * precision * recall / (precision + recall + 1e-8)
    
    pred_ls = bat_pred.detach().numpy()
    label_ls = np.array(bat_label.detach(), dtype=int)

    pred_ls = np.array(bat_pred[bat_mask > 0].detach())
    label_ls = np.array(bat_label[bat_mask > 0].detach(), dtype=int)
    try:
        bat_auc = roc_auc_score(label_ls, pred_ls)
    except ValueError:
        bat_auc = 0

    print("precision: {:.4f} recall: {:.4f} f1_score: {:.4f} auc: {:.4f}".format(precision, recall, f1_score, bat_auc))

    return precision, recall, f1_score, bat_auc

def paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, cur_bat_num, save_img='pred_imgs_raw_BDP'):
    w, h = bat_img.size()[2:4]
    for bat_id in range(bat_img.size()[0]):
        img = Image.fromarray(np.moveaxis(np.array(bat_img * 255.0, dtype=np.uint8)[bat_id, :, :, :], 0, 2))
        label = Image.fromarray(np.array(bat_label * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        pred_class = Image.fromarray(np.array(bat_pred_class * 255.0, dtype=np.uint8)[bat_id, 0, :, :])
        
        res_id = (cur_bat_num - 1) * batch_size + bat_id
        target = Image.new('RGB', (3 * w, h))
        target.paste(img, box = (0, 0))
        target.paste(label, box = (w, 0))
        target.paste(pred_class, box = (2 * w, 0))
        
        target.save(os.path.join(save_img, "result_{}.png".format(res_id)))
    return target

# %%
# set parameters for training
EPOCHS = 50
BATCH_SIZE = 8

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

unet_ins = Unet(img_ch=3, isDeconv=True)
unet_ins.to(device)

criterion = nn.BCELoss()
# criterion =  torch.nn.functional.binary_cross_entropy(inputs, targets, reduction='mean')

optimizer = torch.optim.SGD(unet_ins.parameters(), lr=0.1)

# %%
import warnings
warnings.filterwarnings('ignore')

def model_train(net, optimizer, criterion, epochs=50, batch_size=2):
    
    since = time.time()
    train_loss_list = []
    train_prec_list = []
    valid_loss_list = []
    valid_prec_list = []
    
    best_model_wts = copy.deepcopy(net.state_dict())
    best_epoch_avg_loss = float('inf')
    
    for epoch in range(epochs):
        epoch_tot_loss = 0
        print(f'Epoch [{epoch + 1}/{epochs}]')
        for phase in ['train', 'val']:
            
            if phase == 'train':
                net.train()  
            else:
                net.eval()
            
            x_tensor, y_tensor, m_tensor = load_dataset(mode=phase, resize=True, resize_shape=(256, 256))
    
            num_samples = x_tensor.shape[0]
        
            num_iters = int(np.ceil(num_samples / batch_size))
            shuffle_ids = np.random.permutation(num_samples)
            x_tensor = x_tensor[shuffle_ids, :, :, :]
            y_tensor = y_tensor[shuffle_ids, :, :, :]

            for ite in range(num_iters):
                if not ite == num_iters - 1:
                    start_id, end_id = ite * batch_size, (ite + 1) * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
                else:
                    start_id = ite * batch_size
                    bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
                    bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
                    bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])

                optimizer.zero_grad()
                
                bat_img = bat_img.to(device)
                bat_label = bat_label.to(device)
                
                with torch.set_grad_enabled(phase == 'train'):
                    bat_pred = net(bat_img)
                    loss = criterion(bat_pred, bat_label.float())
                    # masked_pred = bat_pred * bat_mask
                    # masked_label = bat_label * bat_mask
                    # loss = criterion(masked_pred, masked_label.float(), reduction='mean')

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()                     

                if not ite == num_iters - 1:
                    epoch_tot_loss += loss.item()
                else:
                    epoch_tot_loss += loss.item()
                    epoch_avg_loss = epoch_tot_loss / (ite + 1)
                    plint = phase if phase == 'train' else 'valid'
                    print("{} avg_loss : {:.4f} ".format(plint, epoch_avg_loss), end = '')
                    prec, _, _, _ = eval_print_metrics(bat_label.to('cpu'), bat_pred.to('cpu'), bat_mask)
                
            if phase == 'train':
                train_loss_list.append(epoch_avg_loss)
                train_prec_list.append(prec)
            else:
                valid_loss_list.append(epoch_avg_loss)
                valid_prec_list.append(prec)
                
            if phase == 'val' and epoch_avg_loss < best_epoch_avg_loss:
                best_epoch_avg_loss = epoch_avg_loss
                best_model_wts = copy.deepcopy(net.state_dict())
    
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best validation loss: {best_epoch_avg_loss:4f}')
    xepoch = np.arange(epochs, dtype=int)+1
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, layout="constrained")
    
    ax1.plot(xepoch, train_loss_list, label='train')
    ax1.plot(xepoch, valid_loss_list, label='valid')
    ax1.legend(loc="center right")
    ax1.set_ylabel('loss')
    
    ax2.plot(xepoch, train_prec_list, label='train')
    ax2.plot(xepoch, valid_prec_list, label='valid')
    ax2.legend(loc="center right")
    ax2.set_ylabel('precision')
    plt.plot()
    
    net.load_state_dict(best_model_wts)
    return net

# %%
trained_unet = model_train(unet_ins, optimizer, criterion, batch_size=BATCH_SIZE, epochs=100)
# Out:
# Epoch [1/100]
# train avg_loss : 0.5538 precision: 0.1093 recall: 0.1338 f1_score: 0.1203 auc: 0.5294
# valid avg_loss : 2.5038 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.5578
# Epoch [2/100]
# train avg_loss : 0.3588 precision: 0.6667 recall: 0.0001 f1_score: 0.0002 auc: 0.5977
# valid avg_loss : 1.6750 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.5310
# Epoch [3/100]
# train avg_loss : 0.2917 precision: 0.5000 recall: 0.0000 f1_score: 0.0001 auc: 0.6211
# valid avg_loss : 1.3754 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.5545
# Epoch [4/100]
# train avg_loss : 0.2726 precision: 0.9848 recall: 0.0031 f1_score: 0.0063 auc: 0.6165
# valid avg_loss : 1.2782 precision: 0.0000 recall: 0.0000 f1_score: 0.0000 auc: 0.6087
# Epoch [5/100]
# train avg_loss : 0.2621 precision: 0.9067 recall: 0.0461 f1_score: 0.0878 auc: 0.6725
# valid avg_loss : 1.2264 precision: 0.9836 recall: 0.0015 f1_score: 0.0030 auc: 0.6171
# Epoch [6/100]
# train avg_loss : 0.2525 precision: 0.9071 recall: 0.1446 f1_score: 0.2494 auc: 0.7993
# valid avg_loss : 1.1742 precision: 0.9172 recall: 0.0559 f1_score: 0.1054 auc: 0.7241
# Epoch [7/100]
# train avg_loss : 0.2444 precision: 0.8161 recall: 0.1930 f1_score: 0.3122 auc: 0.7844
# valid avg_loss : 1.1281 precision: 0.8603 recall: 0.1366 f1_score: 0.2358 auc: 0.7542
# Epoch [8/100]
# train avg_loss : 0.2365 precision: 0.7254 recall: 0.2195 f1_score: 0.3371 auc: 0.7677
# valid avg_loss : 1.0928 precision: 0.8725 recall: 0.1917 f1_score: 0.3144 auc: 0.8028
# Epoch [9/100]
# train avg_loss : 0.2279 precision: 0.8325 recall: 0.3167 f1_score: 0.4589 auc: 0.8571
# valid avg_loss : 1.1054 precision: 0.3855 recall: 0.4196 f1_score: 0.4018 auc: 0.7530
# Epoch [10/100]
# train avg_loss : 0.2237 precision: 0.7749 recall: 0.3717 f1_score: 0.5024 auc: 0.8600
# valid avg_loss : 1.0437 precision: 0.8862 recall: 0.1582 f1_score: 0.2685 auc: 0.7967
# Epoch [11/100]
# train avg_loss : 0.2197 precision: 0.4301 recall: 0.2639 f1_score: 0.3271 auc: 0.6908
# valid avg_loss : 1.0078 precision: 0.7806 recall: 0.2514 f1_score: 0.3803 auc: 0.8003
# Epoch [12/100]
# train avg_loss : 0.2166 precision: 0.5643 recall: 0.3145 f1_score: 0.4039 auc: 0.7650
# valid avg_loss : 0.9943 precision: 0.7882 recall: 0.3164 f1_score: 0.4516 auc: 0.8352
# Epoch [13/100]
# train avg_loss : 0.2146 precision: 0.3932 recall: 0.2259 f1_score: 0.2870 auc: 0.6647
# valid avg_loss : 0.9889 precision: 0.8584 recall: 0.2516 f1_score: 0.3891 auc: 0.8521
# Epoch [14/100]
# train avg_loss : 0.2068 precision: 0.6667 recall: 0.3149 f1_score: 0.4278 auc: 0.8490
# valid avg_loss : 0.9630 precision: 0.7086 recall: 0.2979 f1_score: 0.4194 auc: 0.8363
# Epoch [15/100]
# train avg_loss : 0.2056 precision: 0.5705 recall: 0.4364 f1_score: 0.4945 auc: 0.8222
# valid avg_loss : 0.9284 precision: 0.7674 recall: 0.5061 f1_score: 0.6099 auc: 0.9125
# Epoch [16/100]
# train avg_loss : 0.2038 precision: 0.5571 recall: 0.4155 f1_score: 0.4760 auc: 0.7981
# valid avg_loss : 0.9233 precision: 0.7517 recall: 0.5331 f1_score: 0.6238 auc: 0.9037
# Epoch [17/100]
# train avg_loss : 0.2014 precision: 0.7026 recall: 0.4422 f1_score: 0.5428 auc: 0.8991
# valid avg_loss : 0.9249 precision: 0.8142 recall: 0.3557 f1_score: 0.4951 auc: 0.8755
# Epoch [18/100]
# train avg_loss : 0.2028 precision: 0.5889 recall: 0.4093 f1_score: 0.4829 auc: 0.7974
# valid avg_loss : 0.9540 precision: 0.8497 recall: 0.2183 f1_score: 0.3473 auc: 0.8292
# Epoch [19/100]
# train avg_loss : 0.1974 precision: 0.6813 recall: 0.5415 f1_score: 0.6034 auc: 0.9110
# valid avg_loss : 0.8965 precision: 0.6609 recall: 0.6140 f1_score: 0.6366 auc: 0.9058
# Epoch [20/100]
# train avg_loss : 0.1956 precision: 0.7114 recall: 0.5631 f1_score: 0.6287 auc: 0.9257
# valid avg_loss : 0.8810 precision: 0.7583 recall: 0.4859 f1_score: 0.5923 auc: 0.9077
# Epoch [21/100]
# train avg_loss : 0.1964 precision: 0.7824 recall: 0.5505 f1_score: 0.6463 auc: 0.9252
# valid avg_loss : 0.8846 precision: 0.7885 recall: 0.4800 f1_score: 0.5968 auc: 0.9100
# Epoch [22/100]
# train avg_loss : 0.1955 precision: 0.7334 recall: 0.5513 f1_score: 0.6294 auc: 0.9174
# valid avg_loss : 0.9007 precision: 0.7870 recall: 0.4141 f1_score: 0.5427 auc: 0.8905
# Epoch [23/100]
# train avg_loss : 0.1944 precision: 0.6402 recall: 0.5285 f1_score: 0.5790 auc: 0.9069
# valid avg_loss : 0.9135 precision: 0.7568 recall: 0.4079 f1_score: 0.5301 auc: 0.8416
# Epoch [24/100]
# train avg_loss : 0.1944 precision: 0.7502 recall: 0.5282 f1_score: 0.6200 auc: 0.9224
# valid avg_loss : 0.8787 precision: 0.7079 recall: 0.5411 f1_score: 0.6134 auc: 0.8936
# Epoch [25/100]
# train avg_loss : 0.2007 precision: 0.7610 recall: 0.5339 f1_score: 0.6276 auc: 0.9220
# valid avg_loss : 0.9087 precision: 0.7756 recall: 0.3221 f1_score: 0.4551 auc: 0.8853
# Epoch [26/100]
# train avg_loss : 0.1953 precision: 0.4669 recall: 0.3000 f1_score: 0.3653 auc: 0.7466
# valid avg_loss : 0.8862 precision: 0.7803 recall: 0.4040 f1_score: 0.5324 auc: 0.9018
# Epoch [27/100]
# train avg_loss : 0.1897 precision: 0.7032 recall: 0.5583 f1_score: 0.6224 auc: 0.9217
# valid avg_loss : 0.8560 precision: 0.7036 recall: 0.5225 f1_score: 0.5997 auc: 0.9067
# Epoch [28/100]
# train avg_loss : 0.1954 precision: 0.5094 recall: 0.3954 f1_score: 0.4452 auc: 0.8088
# valid avg_loss : 0.8820 precision: 0.7811 recall: 0.4682 f1_score: 0.5855 auc: 0.9166
# Epoch [29/100]
# train avg_loss : 0.1901 precision: 0.7198 recall: 0.6113 f1_score: 0.6611 auc: 0.9379
# valid avg_loss : 0.8674 precision: 0.8009 recall: 0.3969 f1_score: 0.5308 auc: 0.9032
# Epoch [30/100]
# train avg_loss : 0.1906 precision: 0.5429 recall: 0.4639 f1_score: 0.5003 auc: 0.8271
# valid avg_loss : 0.8594 precision: 0.7998 recall: 0.4303 f1_score: 0.5595 auc: 0.9079
# Epoch [31/100]
# train avg_loss : 0.1921 precision: 0.5248 recall: 0.4031 f1_score: 0.4559 auc: 0.7864
# valid avg_loss : 0.8654 precision: 0.7394 recall: 0.4572 f1_score: 0.5650 auc: 0.9123
# Epoch [32/100]
# train avg_loss : 0.1931 precision: 0.5545 recall: 0.4383 f1_score: 0.4896 auc: 0.7780
# valid avg_loss : 0.8808 precision: 0.8015 recall: 0.3637 f1_score: 0.5003 auc: 0.9081
# Epoch [33/100]
# train avg_loss : 0.1921 precision: 0.5147 recall: 0.3474 f1_score: 0.4148 auc: 0.7517
# valid avg_loss : 0.8834 precision: 0.7906 recall: 0.4156 f1_score: 0.5448 auc: 0.8900
# Epoch [34/100]
# train avg_loss : 0.1873 precision: 0.5688 recall: 0.5524 f1_score: 0.5605 auc: 0.9163
# valid avg_loss : 0.8691 precision: 0.7554 recall: 0.4340 f1_score: 0.5513 auc: 0.8815
# Epoch [35/100]
# train avg_loss : 0.1907 precision: 0.7151 recall: 0.4956 f1_score: 0.5855 auc: 0.8559
# valid avg_loss : 0.8869 precision: 0.7629 recall: 0.4205 f1_score: 0.5421 auc: 0.8881
# Epoch [36/100]
# train avg_loss : 0.1899 precision: 0.6949 recall: 0.4839 f1_score: 0.5705 auc: 0.8786
# valid avg_loss : 0.8630 precision: 0.7423 recall: 0.4358 f1_score: 0.5492 auc: 0.9119
# Epoch [37/100]
# train avg_loss : 0.1882 precision: 0.5525 recall: 0.4527 f1_score: 0.4976 auc: 0.8374
# valid avg_loss : 0.8523 precision: 0.7761 recall: 0.4737 f1_score: 0.5883 auc: 0.9146
# Epoch [38/100]
# train avg_loss : 0.1878 precision: 0.5728 recall: 0.4913 f1_score: 0.5289 auc: 0.8566
# valid avg_loss : 0.8522 precision: 0.7952 recall: 0.4415 f1_score: 0.5678 auc: 0.9209
# Epoch [39/100]
# train avg_loss : 0.1856 precision: 0.7028 recall: 0.5889 f1_score: 0.6409 auc: 0.9308
# valid avg_loss : 0.8363 precision: 0.7730 recall: 0.5007 f1_score: 0.6077 auc: 0.9302
# Epoch [40/100]
# train avg_loss : 0.1833 precision: 0.6381 recall: 0.6470 f1_score: 0.6425 auc: 0.9381
# valid avg_loss : 0.8181 precision: 0.7242 recall: 0.6252 f1_score: 0.6711 auc: 0.9375
# Epoch [41/100]
# train avg_loss : 0.1863 precision: 0.6833 recall: 0.6065 f1_score: 0.6426 auc: 0.9325
# valid avg_loss : 0.8366 precision: 0.6765 recall: 0.6436 f1_score: 0.6596 auc: 0.9232
# Epoch [42/100]
# train avg_loss : 0.1829 precision: 0.5928 recall: 0.5910 f1_score: 0.5919 auc: 0.9238
# valid avg_loss : 0.8213 precision: 0.7069 recall: 0.5540 f1_score: 0.6212 auc: 0.9200
# Epoch [43/100]
# train avg_loss : 0.1889 precision: 0.4876 recall: 0.4426 f1_score: 0.4640 auc: 0.8429
# valid avg_loss : 0.8467 precision: 0.7463 recall: 0.4803 f1_score: 0.5845 auc: 0.9092
# Epoch [44/100]
# train avg_loss : 0.1863 precision: 0.5597 recall: 0.4914 f1_score: 0.5234 auc: 0.8332
# valid avg_loss : 0.8416 precision: 0.7563 recall: 0.4979 f1_score: 0.6005 auc: 0.9231
# Epoch [45/100]
# train avg_loss : 0.1829 precision: 0.7278 recall: 0.6261 f1_score: 0.6731 auc: 0.9418
# valid avg_loss : 0.8268 precision: 0.7853 recall: 0.4916 f1_score: 0.6046 auc: 0.9322
# Epoch [46/100]
# train avg_loss : 0.1824 precision: 0.7291 recall: 0.6445 f1_score: 0.6842 auc: 0.9364
# valid avg_loss : 0.8181 precision: 0.7087 recall: 0.5288 f1_score: 0.6057 auc: 0.9285
# Epoch [47/100]
# train avg_loss : 0.1841 precision: 0.6280 recall: 0.5215 f1_score: 0.5698 auc: 0.8690
# valid avg_loss : 0.8335 precision: 0.7824 recall: 0.4434 f1_score: 0.5660 auc: 0.9280
# Epoch [48/100]
# train avg_loss : 0.1826 precision: 0.7139 recall: 0.5935 f1_score: 0.6482 auc: 0.9355
# valid avg_loss : 0.8338 precision: 0.7576 recall: 0.3985 f1_score: 0.5223 auc: 0.9024
# Epoch [49/100]
# train avg_loss : 0.1864 precision: 0.5646 recall: 0.4494 f1_score: 0.5005 auc: 0.8075
# valid avg_loss : 0.8337 precision: 0.7132 recall: 0.5533 f1_score: 0.6231 auc: 0.9188
# Epoch [50/100]
# train avg_loss : 0.1829 precision: 0.6382 recall: 0.4882 f1_score: 0.5532 auc: 0.8723
# valid avg_loss : 0.8256 precision: 0.7636 recall: 0.5071 f1_score: 0.6095 auc: 0.9162
# Epoch [51/100]
# train avg_loss : 0.1864 precision: 0.5201 recall: 0.3806 f1_score: 0.4395 auc: 0.7458
# valid avg_loss : 0.8623 precision: 0.7766 recall: 0.3641 f1_score: 0.4957 auc: 0.9012
# Epoch [52/100]
# train avg_loss : 0.1828 precision: 0.6758 recall: 0.6197 f1_score: 0.6465 auc: 0.9326
# valid avg_loss : 0.8207 precision: 0.7060 recall: 0.5876 f1_score: 0.6414 auc: 0.9227
# Epoch [53/100]
# train avg_loss : 0.1830 precision: 0.6434 recall: 0.5110 f1_score: 0.5696 auc: 0.8777
# valid avg_loss : 0.8220 precision: 0.7226 recall: 0.5175 f1_score: 0.6031 auc: 0.9227
# Epoch [54/100]
# train avg_loss : 0.1830 precision: 0.5431 recall: 0.5178 f1_score: 0.5301 auc: 0.8582
# valid avg_loss : 0.8174 precision: 0.7272 recall: 0.5878 f1_score: 0.6501 auc: 0.9364
# Epoch [55/100]
# train avg_loss : 0.1834 precision: 0.5552 recall: 0.4559 f1_score: 0.5007 auc: 0.8607
# valid avg_loss : 0.8161 precision: 0.7428 recall: 0.6399 f1_score: 0.6875 auc: 0.9433
# Epoch [56/100]
# train avg_loss : 0.1847 precision: 0.5042 recall: 0.4554 f1_score: 0.4786 auc: 0.8187
# valid avg_loss : 0.8321 precision: 0.7853 recall: 0.5151 f1_score: 0.6221 auc: 0.9318
# Epoch [57/100]
# train avg_loss : 0.1839 precision: 0.5166 recall: 0.4447 f1_score: 0.4780 auc: 0.8142
# valid avg_loss : 0.8232 precision: 0.7286 recall: 0.5558 f1_score: 0.6306 auc: 0.9308
# Epoch [58/100]
# train avg_loss : 0.1862 precision: 0.4660 recall: 0.3655 f1_score: 0.4097 auc: 0.7497
# valid avg_loss : 0.8474 precision: 0.7337 recall: 0.4724 f1_score: 0.5747 auc: 0.9088
# Epoch [59/100]
# train avg_loss : 0.1829 precision: 0.5730 recall: 0.4912 f1_score: 0.5290 auc: 0.8655
# valid avg_loss : 0.8167 precision: 0.7278 recall: 0.5747 f1_score: 0.6423 auc: 0.9240
# Epoch [60/100]
# train avg_loss : 0.1808 precision: 0.7559 recall: 0.5665 f1_score: 0.6476 auc: 0.9418
# valid avg_loss : 0.8123 precision: 0.7114 recall: 0.5825 f1_score: 0.6405 auc: 0.9250
# Epoch [61/100]
# train avg_loss : 0.1806 precision: 0.6240 recall: 0.5136 f1_score: 0.5634 auc: 0.8768
# valid avg_loss : 0.8087 precision: 0.7529 recall: 0.5132 f1_score: 0.6103 auc: 0.9339
# Epoch [62/100]
# train avg_loss : 0.1815 precision: 0.5653 recall: 0.5202 f1_score: 0.5418 auc: 0.8592
# valid avg_loss : 0.8209 precision: 0.7585 recall: 0.5202 f1_score: 0.6172 auc: 0.9274
# Epoch [63/100]
# train avg_loss : 0.1802 precision: 0.7017 recall: 0.6418 f1_score: 0.6704 auc: 0.9428
# valid avg_loss : 0.8421 precision: 0.7974 recall: 0.3557 f1_score: 0.4919 auc: 0.8770
# Epoch [64/100]
# train avg_loss : 0.1780 precision: 0.6438 recall: 0.6690 f1_score: 0.6562 auc: 0.9287
# valid avg_loss : 0.8355 precision: 0.8121 recall: 0.3973 f1_score: 0.5335 auc: 0.8971
# Epoch [65/100]
# train avg_loss : 0.1788 precision: 0.7205 recall: 0.6220 f1_score: 0.6676 auc: 0.9321
# valid avg_loss : 0.7979 precision: 0.6807 recall: 0.6063 f1_score: 0.6413 auc: 0.9360
# Epoch [66/100]
# train avg_loss : 0.1823 precision: 0.4340 recall: 0.4033 f1_score: 0.4181 auc: 0.7665
# valid avg_loss : 0.8171 precision: 0.6961 recall: 0.5806 f1_score: 0.6332 auc: 0.9254
# Epoch [67/100]
# train avg_loss : 0.1813 precision: 0.5023 recall: 0.5032 f1_score: 0.5028 auc: 0.8601
# valid avg_loss : 0.8279 precision: 0.7979 recall: 0.4823 f1_score: 0.6012 auc: 0.9179
# Epoch [68/100]
# train avg_loss : 0.1848 precision: 0.3026 recall: 0.2808 f1_score: 0.2913 auc: 0.7069
# valid avg_loss : 0.8405 precision: 0.7888 recall: 0.3819 f1_score: 0.5146 auc: 0.9020
# Epoch [69/100]
# train avg_loss : 0.1805 precision: 0.4987 recall: 0.5118 f1_score: 0.5052 auc: 0.8365
# valid avg_loss : 0.8179 precision: 0.6942 recall: 0.5124 f1_score: 0.5896 auc: 0.9168
# Epoch [70/100]
# train avg_loss : 0.1786 precision: 0.5064 recall: 0.4773 f1_score: 0.4914 auc: 0.8350
# valid avg_loss : 0.8119 precision: 0.7643 recall: 0.4064 f1_score: 0.5306 auc: 0.9181
# Epoch [71/100]
# train avg_loss : 0.1779 precision: 0.7195 recall: 0.6731 f1_score: 0.6955 auc: 0.9499
# valid avg_loss : 0.7961 precision: 0.7211 recall: 0.6116 f1_score: 0.6618 auc: 0.9415
# Epoch [72/100]
# train avg_loss : 0.1783 precision: 0.7537 recall: 0.6071 f1_score: 0.6725 auc: 0.9434
# valid avg_loss : 0.7982 precision: 0.7089 recall: 0.6479 f1_score: 0.6770 auc: 0.9359
# Epoch [73/100]
# train avg_loss : 0.1788 precision: 0.5711 recall: 0.5366 f1_score: 0.5533 auc: 0.8749
# valid avg_loss : 0.7974 precision: 0.7452 recall: 0.4954 f1_score: 0.5951 auc: 0.9222
# Epoch [74/100]
# train avg_loss : 0.1773 precision: 0.7488 recall: 0.6207 f1_score: 0.6788 auc: 0.9360
# valid avg_loss : 0.7965 precision: 0.7324 recall: 0.5681 f1_score: 0.6398 auc: 0.9356
# Epoch [75/100]
# train avg_loss : 0.1791 precision: 0.5956 recall: 0.5032 f1_score: 0.5455 auc: 0.8380
# valid avg_loss : 0.8031 precision: 0.7466 recall: 0.6135 f1_score: 0.6735 auc: 0.9399
# Epoch [76/100]
# train avg_loss : 0.1787 precision: 0.4936 recall: 0.5246 f1_score: 0.5087 auc: 0.8336
# valid avg_loss : 0.8070 precision: 0.7741 recall: 0.5093 f1_score: 0.6143 auc: 0.9322
# Epoch [77/100]
# train avg_loss : 0.1823 precision: 0.4984 recall: 0.4003 f1_score: 0.4440 auc: 0.7899
# valid avg_loss : 0.8608 precision: 0.8053 recall: 0.3410 f1_score: 0.4792 auc: 0.9068
# Epoch [78/100]
# train avg_loss : 0.1770 precision: 0.6673 recall: 0.6891 f1_score: 0.6780 auc: 0.9565
# valid avg_loss : 0.7950 precision: 0.6914 recall: 0.5797 f1_score: 0.6306 auc: 0.9279
# Epoch [79/100]
# train avg_loss : 0.1782 precision: 0.5080 recall: 0.5624 f1_score: 0.5338 auc: 0.8540
# valid avg_loss : 0.8072 precision: 0.7730 recall: 0.5016 f1_score: 0.6084 auc: 0.9171
# Epoch [80/100]
# train avg_loss : 0.1777 precision: 0.5952 recall: 0.5129 f1_score: 0.5510 auc: 0.8545
# valid avg_loss : 0.7996 precision: 0.7558 recall: 0.5533 f1_score: 0.6389 auc: 0.9366
# Epoch [81/100]
# train avg_loss : 0.1750 precision: 0.7058 recall: 0.6356 f1_score: 0.6689 auc: 0.9447
# valid avg_loss : 0.8026 precision: 0.6699 recall: 0.5271 f1_score: 0.5900 auc: 0.9061
# Epoch [82/100]
# train avg_loss : 0.1785 precision: 0.5894 recall: 0.4889 f1_score: 0.5345 auc: 0.8583
# valid avg_loss : 0.8044 precision: 0.7507 recall: 0.5039 f1_score: 0.6030 auc: 0.9212
# Epoch [83/100]
# train avg_loss : 0.1771 precision: 0.7728 recall: 0.6569 f1_score: 0.7102 auc: 0.9539
# valid avg_loss : 0.7901 precision: 0.7222 recall: 0.6060 f1_score: 0.6590 auc: 0.9406
# Epoch [84/100]
# train avg_loss : 0.1785 precision: 0.5788 recall: 0.4843 f1_score: 0.5273 auc: 0.8555
# valid avg_loss : 0.8013 precision: 0.7529 recall: 0.5333 f1_score: 0.6243 auc: 0.9377
# Epoch [85/100]
# train avg_loss : 0.1841 precision: 0.3227 recall: 0.2745 f1_score: 0.2966 auc: 0.6577
# valid avg_loss : 0.8347 precision: 0.8224 recall: 0.4201 f1_score: 0.5561 auc: 0.9306
# Epoch [86/100]
# train avg_loss : 0.1749 precision: 0.6897 recall: 0.6600 f1_score: 0.6745 auc: 0.9460
# valid avg_loss : 0.7856 precision: 0.7434 recall: 0.6020 f1_score: 0.6653 auc: 0.9462
# Epoch [87/100]
# train avg_loss : 0.1750 precision: 0.5135 recall: 0.5196 f1_score: 0.5166 auc: 0.8636
# valid avg_loss : 0.7823 precision: 0.7036 recall: 0.5804 f1_score: 0.6361 auc: 0.9373
# Epoch [88/100]
# train avg_loss : 0.1775 precision: 0.6079 recall: 0.5521 f1_score: 0.5787 auc: 0.8759
# valid avg_loss : 0.7965 precision: 0.7491 recall: 0.5353 f1_score: 0.6244 auc: 0.9392
# Epoch [89/100]
# train avg_loss : 0.1726 precision: 0.7578 recall: 0.6631 f1_score: 0.7073 auc: 0.9575
# valid avg_loss : 0.7724 precision: 0.7183 recall: 0.6108 f1_score: 0.6602 auc: 0.9375
# Epoch [90/100]
# train avg_loss : 0.1728 precision: 0.6865 recall: 0.6810 f1_score: 0.6837 auc: 0.9418
# valid avg_loss : 0.7799 precision: 0.7937 recall: 0.5592 f1_score: 0.6561 auc: 0.9369
# Epoch [91/100]
# train avg_loss : 0.1738 precision: 0.6662 recall: 0.7085 f1_score: 0.6867 auc: 0.9542
# valid avg_loss : 0.7804 precision: 0.6813 recall: 0.6700 f1_score: 0.6756 auc: 0.9314
# Epoch [92/100]
# train avg_loss : 0.1723 precision: 0.7119 recall: 0.6129 f1_score: 0.6587 auc: 0.9418
# valid avg_loss : 0.7736 precision: 0.7294 recall: 0.6756 f1_score: 0.7015 auc: 0.9420
# Epoch [93/100]
# train avg_loss : 0.1807 precision: 0.3909 recall: 0.3653 f1_score: 0.3777 auc: 0.7374
# valid avg_loss : 0.8181 precision: 0.7812 recall: 0.4765 f1_score: 0.5919 auc: 0.9215
# Epoch [94/100]
# train avg_loss : 0.1750 precision: 0.5853 recall: 0.5778 f1_score: 0.5815 auc: 0.8737
# valid avg_loss : 0.7801 precision: 0.6860 recall: 0.7040 f1_score: 0.6949 auc: 0.9493
# Epoch [95/100]
# train avg_loss : 0.1736 precision: 0.7110 recall: 0.6883 f1_score: 0.6995 auc: 0.9428
# valid avg_loss : 0.7818 precision: 0.7197 recall: 0.6174 f1_score: 0.6646 auc: 0.9370
# Epoch [96/100]
# train avg_loss : 0.1765 precision: 0.4605 recall: 0.3992 f1_score: 0.4277 auc: 0.8010
# valid avg_loss : 0.8102 precision: 0.7100 recall: 0.4232 f1_score: 0.5303 auc: 0.9202
# Epoch [97/100]
# train avg_loss : 0.1746 precision: 0.6931 recall: 0.6540 f1_score: 0.6730 auc: 0.9474
# valid avg_loss : 0.7848 precision: 0.7168 recall: 0.5398 f1_score: 0.6158 auc: 0.9232
# Epoch [98/100]
# train avg_loss : 0.1715 precision: 0.7041 recall: 0.6512 f1_score: 0.6766 auc: 0.9428
# valid avg_loss : 0.7678 precision: 0.7000 recall: 0.5871 f1_score: 0.6386 auc: 0.9341
# Epoch [99/100]
# train avg_loss : 0.1735 precision: 0.5481 recall: 0.5717 f1_score: 0.5597 auc: 0.8626
# valid avg_loss : 0.7800 precision: 0.7011 recall: 0.6569 f1_score: 0.6783 auc: 0.9415
# Epoch [100/100]
# train avg_loss : 0.1713 precision: 0.7251 recall: 0.6409 f1_score: 0.6804 auc: 0.9376
# valid avg_loss : 0.7715 precision: 0.6855 recall: 0.6104 f1_score: 0.6458 auc: 0.9275
# Training complete in 14m 23s
# Best validation loss: 0.767794

# %%
def model_test(net, batch_size=2):
    
    x_tensor, y_tensor, m_tensor = load_dataset(mode='test', resize=True, resize_shape=(256, 256))
    num_samples = x_tensor.shape[0]
    num_iters = int(np.ceil(num_samples / batch_size))
    prec_cul = 0
    rec_cul = 0
    f1_cul = 0
    auc_cul = 0
    for ite in range(num_iters):
        print("predicting on the {}th batch".format(ite + 1))
        if not ite == num_iters - 1:
            start_id, end_id = ite * batch_size, (ite + 1) * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : end_id, :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : end_id, 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : end_id, 0: 1, :, :])
        else:
            start_id = ite * batch_size
            bat_img = torch.Tensor(x_tensor[start_id : , :, :, :])
            bat_label = torch.Tensor(y_tensor[start_id : , 0: 1, :, :])
            bat_mask = torch.Tensor(m_tensor[start_id : , 0: 1, :, :])
            
        bat_pred = net(bat_img.to(device))
        bat_pred = bat_pred.to('cpu')
        bat_pred_class = (bat_pred > 0.35).float() * bat_mask
        
        prec, rec, f1, auc = eval_print_metrics(bat_label, bat_pred, bat_mask)
        prec_cul += prec
        rec_cul += rec
        f1_cul += f1
        auc_cul += auc
        aa = paste_and_save(bat_img, bat_label, bat_pred_class, batch_size, ite + 1)
        plt.imshow(aa)
        plt.title('last image in batch')
        plt.axis('off')
        plt.show()
    print("Testing average\nprecision: {:.2f} % recall: {:.2f} % f1_score: {:.4f} auc: {:.4f}".format(100*prec_cul/num_iters, 100*rec_cul/num_iters, f1_cul/num_iters, auc_cul/num_iters))

    return

if os.path.exists("./pred_imgs_raw_BDP"):
    shutil.rmtree("./pred_imgs_raw_BDP")
os.mkdir("./pred_imgs_raw_BDP")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
a = model_test(trained_unet, batch_size=2)
shutil.rmtree('./datasets_raw_BDP')
# Out:
# predicting on the 1th batch
# precision: 0.7542 recall: 0.7109 f1_score: 0.7319 auc: 0.9534
# predicting on the 2th batch
# precision: 0.7484 recall: 0.6339 f1_score: 0.6864 auc: 0.9366
# predicting on the 3th batch
# precision: 0.6612 recall: 0.7515 f1_score: 0.7035 auc: 0.9510
# predicting on the 4th batch
# precision: 0.5995 recall: 0.7358 f1_score: 0.6607 auc: 0.9421
# predicting on the 5th batch
# precision: 0.6453 recall: 0.6824 f1_score: 0.6633 auc: 0.9346
# predicting on the 6th batch
# precision: 0.6765 recall: 0.5938 f1_score: 0.6325 auc: 0.9526
# Testing average
# precision: 68.08 % recall: 68.47 % f1_score: 0.6797 auc: 0.9451

# %%
torch.save(trained_unet.state_dict(), 'models/unet_100epochs_data_raw_BDP.pt')

# model_ft = model_ft = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=False)
# num_ftrs = model_ft.classifier.in_features
# model_ft.classifier  = nn.Linear(num_ftrs, len(class_names))
# model_ft.load_state_dict(torch.load('models/dens_4b_24e_17m.pt'))

torch.cuda.empty_cache()
