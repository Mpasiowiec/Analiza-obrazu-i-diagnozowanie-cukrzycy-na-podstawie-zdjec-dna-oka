# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

# %%
def imgshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.axis("off")
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
img_size = (300,300)
batch_size = 14
model_name = 'densenet121'
learning_rate = 0.001
num_epochs=50

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(img_size),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor()        
    ]),
    'val': transforms.Compose([
        transforms.Resize(img_size),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor()        
    ]),
    'test': transforms.Compose([
        transforms.Resize(img_size),
        transforms.ToTensor()        
    ])
}

data_dir = 'data/data_m_vessel'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
samples, labels = next(iter(dataloaders['train']))
plt.figure(figsize=(16,24))
grid_imgs = torchvision.utils.make_grid(samples)
imgshow(grid_imgs)

# %%
model_ft = torch.hub.load('pytorch/vision:v0.10.0', model_name, pretrained=True)
num_ftrs = model_ft.classifier.in_features

model_ft.classifier  = nn.Sequential(nn.Linear(num_ftrs, 500),nn.Linear(500,  len(class_names)))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# optimizer_ft = optim.SGD(model_ft.parameters(), lr=learning_rate, momentum=0.9)
optimizer_ft = optim.AdamW(model_ft.parameters(), lr=learning_rate)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Using cache found in C:\Users\micha/.cache\torch\hub\pytorch_vision_v0.10.0
# c:\Users\micha\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\micha\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    train_loss_list = []
    train_acc_list = []
    valid_loss_list = []
    valid_acc_list = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch [{epoch+1}/{num_epochs}]')

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i, data in enumerate(dataloaders[phase], 0):
                inputs, labels = data
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                pred = torch.argmax(outputs, dim=1)
                correct = pred.eq(labels)
                running_corrects += torch.sum(correct.float())
                torch.cuda.empty_cache() 

            epoch_loss = running_loss  / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            if phase == 'train':
                scheduler.step()
                train_loss_list.append(epoch_loss)
                train_acc_list.append(epoch_acc.item())
            else:
                valid_loss_list.append(epoch_loss)
                valid_acc_list.append(epoch_acc.item())                           
            plint = phase if phase == 'train' else 'valid'
            print(f'{plint} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')
    xepoch = np.arange(num_epochs, dtype=int)+1
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, layout="constrained")
    
    ax1.plot(xepoch, train_loss_list, label='train')
    ax1.plot(xepoch, valid_loss_list, label='valid')
    ax1.legend(loc="center right")
    ax1.set_ylabel('loss')
    
    ax2.plot(xepoch, train_acc_list, label='train')
    ax2.plot(xepoch, valid_acc_list, label='valid')
    ax2.legend(loc="center right")
    ax2.set_ylabel('accuracy')
    plt.plot()
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def test_model(model):    
    was_training = model.training
    model.eval()
    test_acc = 0
    for i, data in enumerate(dataloaders['test'], 0):
        samples, labels = data
        with torch.no_grad():
            
            samples, labels = samples.to(device), labels.to(device)
            output = model(samples)
            loss = criterion(output, labels)
            pred = torch.argmax(output, dim=1)
            correct = pred.eq(labels)
            test_acc += torch.sum(correct.float())
            torch.cuda.empty_cache()
            model.train(mode=was_training)
    print('Testing Accuracy: {:.2f} %'.format(100*test_acc/dataset_sizes['test']))

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=num_epochs)
test_model(model_ft)
# Out:
# Epoch [1/50]
# train Loss: 0.8241 Acc: 0.5931
# valid Loss: 0.9405 Acc: 0.6541
# Epoch [2/50]
# train Loss: 0.5458 Acc: 0.7495
# valid Loss: 0.6653 Acc: 0.6917
# Epoch [3/50]
# train Loss: 0.5257 Acc: 0.7516
# valid Loss: 0.7951 Acc: 0.5865
# Epoch [4/50]
# train Loss: 0.4807 Acc: 0.7880
# valid Loss: 0.9268 Acc: 0.6316
# Epoch [5/50]
# train Loss: 0.4966 Acc: 0.7666
# valid Loss: 0.9405 Acc: 0.6015
# Epoch [6/50]
# train Loss: 0.5128 Acc: 0.7623
# valid Loss: 0.8752 Acc: 0.6316
# Epoch [7/50]
# train Loss: 0.4975 Acc: 0.7537
# valid Loss: 2.0508 Acc: 0.5414
# Epoch [8/50]
# train Loss: 0.4633 Acc: 0.7666
# valid Loss: 0.5975 Acc: 0.7068
# Epoch [9/50]
# train Loss: 0.4036 Acc: 0.8116
# valid Loss: 0.6186 Acc: 0.6842
# Epoch [10/50]
# train Loss: 0.3863 Acc: 0.8137
# valid Loss: 0.6197 Acc: 0.6692
# Epoch [11/50]
# train Loss: 0.3526 Acc: 0.8480
# valid Loss: 0.6468 Acc: 0.7293
# Epoch [12/50]
# train Loss: 0.3697 Acc: 0.8373
# valid Loss: 0.7252 Acc: 0.6917
# Epoch [13/50]
# train Loss: 0.3354 Acc: 0.8651
# valid Loss: 0.6583 Acc: 0.6842
# Epoch [14/50]
# train Loss: 0.2839 Acc: 0.8801
# valid Loss: 0.7869 Acc: 0.6391
# Epoch [15/50]
# train Loss: 0.2597 Acc: 0.8929
# valid Loss: 0.6577 Acc: 0.6992
# Epoch [16/50]
# train Loss: 0.2173 Acc: 0.9272
# valid Loss: 0.6890 Acc: 0.6992
# Epoch [17/50]
# train Loss: 0.2340 Acc: 0.9122
# valid Loss: 0.6222 Acc: 0.7068
# Epoch [18/50]
# train Loss: 0.2210 Acc: 0.9186
# valid Loss: 0.6418 Acc: 0.6917
# Epoch [19/50]
# train Loss: 0.1978 Acc: 0.9251
# valid Loss: 0.6052 Acc: 0.6992
# Epoch [20/50]
# train Loss: 0.2077 Acc: 0.9186
# valid Loss: 0.6212 Acc: 0.6992
# Epoch [21/50]
# train Loss: 0.2040 Acc: 0.9165
# valid Loss: 0.6015 Acc: 0.6992
# Epoch [22/50]
# train Loss: 0.1783 Acc: 0.9379
# valid Loss: 0.6726 Acc: 0.6917
# Epoch [23/50]
# train Loss: 0.2102 Acc: 0.9165
# valid Loss: 0.6266 Acc: 0.7068
# Epoch [24/50]
# train Loss: 0.2054 Acc: 0.9229
# valid Loss: 0.6260 Acc: 0.7444
# Epoch [25/50]
# train Loss: 0.1994 Acc: 0.9358
# valid Loss: 0.6743 Acc: 0.7143
# Epoch [26/50]
# train Loss: 0.1800 Acc: 0.9208
# valid Loss: 0.6362 Acc: 0.7293
# Epoch [27/50]
# train Loss: 0.2328 Acc: 0.9101
# valid Loss: 0.6235 Acc: 0.6842
# Epoch [28/50]
# train Loss: 0.1983 Acc: 0.9272
# valid Loss: 0.6302 Acc: 0.7218
# Epoch [29/50]
# train Loss: 0.1865 Acc: 0.9336
# valid Loss: 0.7104 Acc: 0.6767
# Epoch [30/50]
# train Loss: 0.1714 Acc: 0.9422
# valid Loss: 0.6833 Acc: 0.6917
# Epoch [31/50]
# train Loss: 0.2039 Acc: 0.9143
# valid Loss: 0.6570 Acc: 0.6767
# Epoch [32/50]
# train Loss: 0.1873 Acc: 0.9315
# valid Loss: 0.6434 Acc: 0.7143
# Epoch [33/50]
# train Loss: 0.2005 Acc: 0.9251
# valid Loss: 0.6606 Acc: 0.6692
# Epoch [34/50]
# train Loss: 0.2100 Acc: 0.9336
# valid Loss: 0.5975 Acc: 0.7143
# Epoch [35/50]
# train Loss: 0.1805 Acc: 0.9336
# valid Loss: 0.5577 Acc: 0.7068
# Epoch [36/50]
# train Loss: 0.2016 Acc: 0.9186
# valid Loss: 0.6549 Acc: 0.7444
# Epoch [37/50]
# train Loss: 0.2087 Acc: 0.9186
# valid Loss: 0.6824 Acc: 0.6917
# Epoch [38/50]
# train Loss: 0.1832 Acc: 0.9422
# valid Loss: 0.6426 Acc: 0.7293
# Epoch [39/50]
# train Loss: 0.1734 Acc: 0.9336
# valid Loss: 0.6744 Acc: 0.6842
# Epoch [40/50]
# train Loss: 0.1727 Acc: 0.9422
# valid Loss: 0.6346 Acc: 0.6917
# Epoch [41/50]
# train Loss: 0.2159 Acc: 0.9208
# valid Loss: 0.6343 Acc: 0.7218
# Epoch [42/50]
# train Loss: 0.1808 Acc: 0.9315
# valid Loss: 0.6457 Acc: 0.6992
# Epoch [43/50]
# train Loss: 0.1994 Acc: 0.9122
# valid Loss: 0.7056 Acc: 0.6992
# Epoch [44/50]
# train Loss: 0.2054 Acc: 0.9229
# valid Loss: 0.6082 Acc: 0.7218
# Epoch [45/50]
# train Loss: 0.1673 Acc: 0.9422
# valid Loss: 0.6208 Acc: 0.7068
# Epoch [46/50]
# train Loss: 0.1859 Acc: 0.9186
# valid Loss: 0.5569 Acc: 0.6917
# Epoch [47/50]
# train Loss: 0.1797 Acc: 0.9443
# valid Loss: 0.6156 Acc: 0.6917
# Epoch [48/50]
# train Loss: 0.1783 Acc: 0.9336
# valid Loss: 0.7140 Acc: 0.6842
# Epoch [49/50]
# train Loss: 0.1891 Acc: 0.9315
# valid Loss: 0.6016 Acc: 0.7293
# Epoch [50/50]
# train Loss: 0.1711 Acc: 0.9379
# valid Loss: 0.6483 Acc: 0.6917
# Training complete in 24m 13s
# Best val Acc: 0.744361
# Testing Accuracy: 80.00 %

# %%
torch.save(model_ft.state_dict(), f'models/{model_name}_vessel_e{num_epochs}_s{img_size[0]}_b{batch_size}.pt')

# model_ft = model_ft = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', pretrained=False)
# num_ftrs = model_ft.classifier.in_features
# model_ft.classifier  = nn.Sequential(nn.Linear(num_ftrs, 500),nn.Linear(500,  len(class_names)))
# model_ft.load_state_dict(torch.load('models/dens_4b_24e_17m.pt'))

torch.cuda.empty_cache()
